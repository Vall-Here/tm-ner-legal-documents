# %% [markdown]
# # Evaluasi NER Model pada Dokumen PDF Real
#
# Notebook ini melakukan evaluasi model NER yang telah dilatih pada dokumen PDF real dari folder `Datasets/PDF`.
#
# ## Tujuan Evaluasi:
#
# 1. Menghitung persentase dokumen yang berhasil diekstrak entitasnya
# 2. Menghitung rata-rata entity yang berhasil diekstrak per dokumen
# 3. Analisis distribusi entity yang ditemukan
# 4. Identifikasi dokumen yang gagal diproses

# %%
# Import required libraries
import os
import sys
import json
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification
import PyPDF2
import re
from typing import List, Dict, Any, Tuple
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter, defaultdict
import warnings
warnings.filterwarnings('ignore')

# Set up paths
PDF_FOLDER = "../../Datasets/PDF"
MODEL_PATH = "models/model_final/model_artifacts"
CONFIG_PATH = "models/model_final"

print("Libraries imported successfully!")
print(f"PDF folder path: {PDF_FOLDER}")
print(f"Model path: {MODEL_PATH}")
print(f"Config path: {CONFIG_PATH}")
# Out:
# Libraries imported successfully!
# PDF folder path: ../../Datasets/PDF
# Model path: models/model_final/model_artifacts
# Config path: models/model_final

# %%
import os
import re
import json
import torch
import random
from typing import List, Dict, Tuple
from transformers import AutoTokenizer, AutoModelForTokenClassification
import PyPDF2

class PDFNEREvaluator:
    """Class untuk melakukan evaluasi NER pada dokumen PDF"""
    
    def __init__(self, model_path: str, config_path: str):
        self.model_path = model_path
        self.config_path = config_path
        self.tokenizer = None
        self.model = None
        self.label_mappings = None
        self.max_length = 512
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        # Expected entity types untuk evaluasi
        self.expected_entities = [
            "Jenis Amar", "Jenis Dakwaan", "Jenis Perkara", 
            "Melanggar UU (Dakwaan)", "Melanggar UU (Pertimbangan Hukum)", "Melanggar UU (Tuntutan)",
            "Nama Hakim Anggota", "Nama Hakim Ketua", "Nama Jaksa", "Nama Panitera", 
            "Nama Pengacara", "Nama Pengadilan", "Nama Saksi", "Nama Terdakwa",
            "Nomor Putusan", "Putusan Hukuman", "Tanggal Kejadian", "Tanggal Putusan",
            "Tingkat Kasus", "Tuntutan Hukuman"
        ]
        
        print(f"Evaluator initialized for device: {self.device}")
    
    def load_model(self) -> bool:
        """Load model dan konfigurasi"""
        try:
            print("Loading model and tokenizer...")
            
            # Check if paths exist
            if not os.path.exists(self.model_path):
                print(f"❌ Model path not found: {self.model_path}")
                return False
            
            if not os.path.exists(self.config_path):
                print(f"❌ Config path not found: {self.config_path}")
                return False
            
            # Load model dan tokenizer
            self.tokenizer = AutoTokenizer.from_pretrained(self.model_path)
            self.model = AutoModelForTokenClassification.from_pretrained(self.model_path)
            self.model.to(self.device)
            self.model.eval()
            
            # Load label mappings
            label_file = os.path.join(self.config_path, "label_mappings.json")
            if not os.path.exists(label_file):
                print(f"❌ Label mappings file not found: {label_file}")
                return False
                
            with open(label_file, 'r', encoding='utf-8') as f:
                self.label_mappings = json.load(f)
            
            # Load model config
            config_file = os.path.join(self.config_path, "model_config.json")
            if os.path.exists(config_file):
                with open(config_file, 'r', encoding='utf-8') as f:
                    config = json.load(f)
                    self.max_length = config.get('max_length', 512)
            else:
                print("⚠️  model_config.json not found, using default max_length=512")
            
            print(f"✅ Model loaded successfully! Max length: {self.max_length}")
            print(f"Number of labels: {len(self.label_mappings['id2label'])}")
            return True
            
        except Exception as e:
            print(f"❌ Error loading model: {e}")
            return False
    
    def clean_text(self, text: str) -> str:
        """Clean dan normalize text"""
        try:
            if not isinstance(text, str):
                text = str(text)
            
            # Remove null bytes dan karakter bermasalah
            text = text.replace('\x00', '')
            
            # Normalize whitespace
            text = re.sub(r'\s+', ' ', text)
            
            # Handle quotes
            text = text.replace('"', '"').replace('"', '"').replace('„', '"')
            text = text.replace(''', "'").replace(''', "'")
            
            # Remove excessive punctuation
            text = re.sub(r'\.{3,}', '...', text)
            
            # Keep printable characters
            printable_chars = []
            for char in text:
                if ord(char) >= 32 or char in ['\n', '\t']:
                    printable_chars.append(char)
            
            text = ''.join(printable_chars)
            return text.strip()
            
        except Exception as e:
            print(f"Error in clean_text: {e}")
            return ""
    
    def extract_text_from_pdf(self, pdf_path: str) -> str:
        """Extract text dari file PDF"""
        try:
            with open(pdf_path, 'rb') as file:
                pdf_reader = PyPDF2.PdfReader(file)
                text = ""
                
                for page in pdf_reader.pages:
                    page_text = page.extract_text()
                    if page_text:  # Only add non-empty pages
                        text += page_text + "\n"
                
                cleaned_text = self.clean_text(text)
                print(f"  📄 Extracted {len(cleaned_text)} characters from {len(pdf_reader.pages)} pages")
                return cleaned_text
                
        except Exception as e:
            print(f"  ❌ Error extracting PDF {pdf_path}: {str(e)}")
            return ""
    
    def predict_entities(self, text: str) -> Tuple[List[Dict], str]:
        """Predict named entities dalam text"""
        try:
            if not text.strip():
                return [], "No text provided"
            
            words = text.split()
            print(f"  🔤 Text has {len(words)} words")
            
            # Pilih strategi berdasarkan panjang text
            if len(words) > 2000:  # Text sangat panjang
                print(f"  📊 Using sliding window strategy")
                return self._predict_with_sliding_window(text, words)
            elif len(words) > 400:  # Text panjang
                print(f"  📊 Using chunking strategy")
                return self._predict_with_chunking(text, words)
            else:  # Text pendek
                print(f"  📊 Using single chunk strategy")
                return self._predict_single_chunk(text, words)
                
        except Exception as e:
            return [], f"Error during prediction: {str(e)}"
    
    def _predict_single_chunk(self, text: str, words: List[str]) -> Tuple[List[Dict], str]:
        """Predict entities untuk single chunk"""
        try:
            # Tokenize
            encoding = self.tokenizer(
                text,
                return_tensors="pt",
                return_offsets_mapping=True,
                truncation=True,
                max_length=self.max_length,
                padding="max_length"
            )
            
            word_ids = encoding.word_ids(batch_index=0)
            offset_mapping = encoding.pop('offset_mapping')
            
            # Move to device
            encoding = {k: v.to(self.device) for k, v in encoding.items()}
            
            # Predict
            with torch.no_grad():
                outputs = self.model(**encoding)
                predictions = torch.argmax(outputs.logits, dim=2)[0].tolist()
            
            # Convert predictions ke labels
            predicted_labels = [self.label_mappings['id2label'][str(pred)] for pred in predictions]
            
            # Extract entities
            entities = self._extract_entities_from_predictions(words, predicted_labels, word_ids)
            
            return entities, "Success"
            
        except Exception as e:
            return [], f"Error during single chunk prediction: {str(e)}"
    
    def _predict_with_chunking(self, text: str, words: List[str]) -> Tuple[List[Dict], str]:
        """Predict entities menggunakan chunking strategy"""
        try:
            chunk_size = 400
            overlap = 50
            all_entities = []
            processed_words = 0
            
            while processed_words < len(words):
                start_idx = max(0, processed_words - overlap if processed_words > 0 else 0)
                end_idx = min(len(words), processed_words + chunk_size)
                
                chunk_words = words[start_idx:end_idx]
                chunk_text = ' '.join(chunk_words)
                
                try:
                    chunk_entities, _ = self._predict_single_chunk(chunk_text, chunk_words)
                    
                    # Adjust entity positions dan hindari duplikasi
                    for entity in chunk_entities:
                        entity['start'] += start_idx
                        entity['end'] += start_idx
                        
                        # Check duplikasi
                        is_duplicate = False
                        for existing_entity in all_entities:
                            if (entity['text'] == existing_entity['text'] and 
                                entity['label'] == existing_entity['label'] and
                                abs(entity['start'] - existing_entity['start']) <= overlap):
                                is_duplicate = True
                                break
                        
                        if not is_duplicate:
                            all_entities.append(entity)
                    
                except Exception:
                    continue
                
                processed_words += chunk_size
            
            # Sort entities by position
            all_entities.sort(key=lambda x: x['start'])
            
            return all_entities, "Success with chunking"
            
        except Exception as e:
            return [], f"Error during chunking prediction: {str(e)}"
    
    def _predict_with_sliding_window(self, text: str, words: List[str], 
                                   window_size: int = 400, stride: int = 200) -> Tuple[List[Dict], str]:
        """Sliding window method untuk dokumen sangat panjang"""
        try:
            all_entities = []
            entity_tracker = set()
            
            for start in range(0, len(words), stride):
                end = min(start + window_size, len(words))
                window_words = words[start:end]
                window_text = ' '.join(window_words)
                
                try:
                    window_entities, _ = self._predict_single_chunk(window_text, window_words)
                    
                    for entity in window_entities:
                        entity['start'] += start
                        entity['end'] += start
                        
                        # Create unique identifier
                        entity_id = (entity['text'], entity['label'], entity['start'])
                        
                        if entity_id not in entity_tracker:
                            entity_tracker.add(entity_id)
                            all_entities.append(entity)
                    
                except Exception:
                    continue
            
            all_entities.sort(key=lambda x: x['start'])
            
            return all_entities, "Success with sliding window"
            
        except Exception as e:
            return [], f"Error during sliding window prediction: {str(e)}"
    
    def _extract_entities_from_predictions(self, words: List[str], predicted_labels: List[str], 
                                         word_ids: List[int]) -> List[Dict]:
        """Extract entities dari predictions"""
        entities = []
        current_entity = None
        
        for i, (word_id, label) in enumerate(zip(word_ids, predicted_labels)):
            if word_id is None:
                continue
                
            if label.startswith('B-'):
                # Simpan entity sebelumnya jika ada
                if current_entity:
                    entities.append(current_entity)
                
                # Mulai entity baru
                entity_type = label[2:]
                current_entity = {
                    'text': words[word_id] if word_id < len(words) else '',
                    'label': entity_type,
                    'start': word_id,
                    'end': word_id
                }
                
            elif label.startswith('I-') and current_entity:
                # Lanjutkan entity yang sudah ada
                entity_type = label[2:]
                if entity_type == current_entity['label']:
                    if word_id < len(words):
                        current_entity['text'] += ' ' + words[word_id]
                        current_entity['end'] = word_id
                else:
                    # Entity type berubah, simpan yang lama
                    entities.append(current_entity)
                    current_entity = None
                    
            else:
                # Label O atau tidak cocok, akhiri entity
                if current_entity:
                    entities.append(current_entity)
                    current_entity = None
        
        # Simpan entity terakhir
        if current_entity:
            entities.append(current_entity)
        
        return entities

print("✅ PDFNEREvaluator class defined successfully!")
# Out:
# ✅ PDFNEREvaluator class defined successfully!

# %%
# Initialize evaluator dan load model
print("🚀 Initializing NER Evaluator...")
evaluator = PDFNEREvaluator(MODEL_PATH, CONFIG_PATH)

print("\n📦 Loading model...")
if evaluator.load_model():
    print("✅ Model loaded successfully!")
    print(f"Expected entity types: {len(evaluator.expected_entities)}")
    print("Entity types:", evaluator.expected_entities[:5], "... (and 15 more)")
else:
    print("❌ Failed to load model!")
    print("Please check if the model files exist in the correct paths.")
    
print(f"\n🎯 Device being used: {evaluator.device}")
# Out:
# 🚀 Initializing NER Evaluator...
# Evaluator initialized for device: cuda
#
# 📦 Loading model...
# Loading model and tokenizer...
# ✅ Model loaded successfully! Max length: 512
# Number of labels: 41
# ✅ Model loaded successfully!
# Expected entity types: 20
# Entity types: ['Jenis Amar', 'Jenis Dakwaan', 'Jenis Perkara', 'Melanggar UU (Dakwaan)', 'Melanggar UU (Pertimbangan Hukum)'] ... (and 15 more)
#
# 🎯 Device being used: cuda

# %%
# Initialize evaluator dan load model
evaluator = PDFNEREvaluator(MODEL_PATH, CONFIG_PATH)

if evaluator.load_model():
    print("✅ Model loaded successfully!")
    print(f"Expected entity types: {len(evaluator.expected_entities)}")
    print("Entity types:", evaluator.expected_entities)
else:
    print("❌ Failed to load model!")
    sys.exit(1)
# Out:
# Evaluator initialized for device: cuda
# Loading model and tokenizer...
# ✅ Model loaded successfully! Max length: 512
# Number of labels: 41
# ✅ Model loaded successfully!
# Expected entity types: 20
# Entity types: ['Jenis Amar', 'Jenis Dakwaan', 'Jenis Perkara', 'Melanggar UU (Dakwaan)', 'Melanggar UU (Pertimbangan Hukum)', 'Melanggar UU (Tuntutan)', 'Nama Hakim Anggota', 'Nama Hakim Ketua', 'Nama Jaksa', 'Nama Panitera', 'Nama Pengacara', 'Nama Pengadilan', 'Nama Saksi', 'Nama Terdakwa', 'Nomor Putusan', 'Putusan Hukuman', 'Tanggal Kejadian', 'Tanggal Putusan', 'Tingkat Kasus', 'Tuntutan Hukuman']

# %%
import random

# Get list of PDF files
pdf_files = [f for f in os.listdir(PDF_FOLDER) if f.endswith('.pdf')]
total_pdfs = len(pdf_files)

print(f"Found {total_pdfs} PDF files in {PDF_FOLDER}")
print(f"First 10 files: {pdf_files[:10]}")

# Randomly select 100 documents for evaluation
TEST_LIMIT = 100  # Set ke None untuk process semua file
if TEST_LIMIT and TEST_LIMIT < total_pdfs:
    # Random selection instead of first N files
    random.seed(42)  # For reproducible results
    pdf_files = random.sample(pdf_files, TEST_LIMIT)
    print(f"\n🎲 Randomly selected {TEST_LIMIT} files for evaluation")
else:
    print(f"\n📄 Processing all {total_pdfs} files")

print(f"\nWill process {len(pdf_files)} PDF files")
print(f"Selected files sample: {pdf_files[:5]} ... (and {len(pdf_files)-5} more)")
# Out:
# Found 474 PDF files in ../../Datasets/PDF
# First 10 files: ['00bf3ce180e4a05c45c16f6fe3b6d883.pdf', '01ca80c986dd13d8998da912acfee601.pdf', '0562ade93fdb9218eb4c383fda670b99.pdf', '0840279ae7740fc264906da509eb77e0.pdf', '0a806b55b86a9b40d581ddd10ab5c552.pdf', '0ad24ecd444045ea8834f2dcab3faea9.pdf', '0bc2ad597f9aa2bd8758f1fac16c479b.pdf', '105e1007b5edd3096341025a5ac71d49.pdf', '10936c2b89b4ce29f943687272489d85.pdf', '10e1c3597cfeb112b3b957609972b996.pdf']
#
# 🎲 Randomly selected 100 files for evaluation
#
# Will process 100 PDF files
# Selected files sample: ['zaecf1371060e0ce917e313435323134.pdf', '67791a1f69a102e1ace1cfb512a6c9c8.pdf', '14981a64360d15393fd496717bc02bae.pdf', 'zaed536065ba50ce8d3d313235353030.pdf', 'd58b2248f65017a12df0d3d31a8ebf8b.pdf'] ... (and 95 more)

# %%
# Process PDF files dan extract entities
results = []
failed_files = []
entity_counter = Counter()
processing_stats = {
    'successful_extractions': 0,
    'failed_extractions': 0,
    'empty_extractions': 0,
    'total_entities_found': 0
}

print("🚀 Starting PDF processing...\n")

for i, pdf_file in enumerate(pdf_files, 1):
    pdf_path = os.path.join(PDF_FOLDER, pdf_file)
    
    print(f"[{i}/{len(pdf_files)}] Processing: {pdf_file}")
    
    try:
        # Extract text dari PDF
        text = evaluator.extract_text_from_pdf(pdf_path)
        
        if not text.strip():
            print(f"  ⚠️  Empty text extracted")
            failed_files.append({
                'file': pdf_file,
                'error': 'Empty text extracted',
                'stage': 'text_extraction',
                'text_length': 0
            })
            processing_stats['empty_extractions'] += 1
            continue
        
        # Analyze extracted text quality
        text_length = len(text)
        word_count = len(text.split())
        
        # Check if text seems meaningful (not just garbage)
        if word_count < 10:
            print(f"  ⚠️  Very short text extracted ({word_count} words)")
            failed_files.append({
                'file': pdf_file,
                'error': f'Very short text extracted ({word_count} words)',
                'stage': 'text_extraction',
                'text_length': text_length
            })
            processing_stats['empty_extractions'] += 1
            continue
        
        # Show first few words for debugging
        sample_text = ' '.join(text.split()[:15]) + "..."
        print(f"  📄 Text sample: {sample_text}")
        print(f"  📊 Text stats: {word_count} words, {text_length} chars")
        
        # Predict entities
        entities, status = evaluator.predict_entities(text)
        
        if "Error" in status:
            print(f"  ❌ Prediction failed: {status}")
            failed_files.append({
                'file': pdf_file,
                'error': status,
                'stage': 'entity_prediction'
            })
            processing_stats['failed_extractions'] += 1
            continue
        
        # Process hasil
        entity_types_found = set()
        entities_by_type = defaultdict(list)
        
        for entity in entities:
            entity_type = entity['label']
            entity_types_found.add(entity_type)
            entities_by_type[entity_type].append(entity)
            entity_counter[entity_type] += 1
        
        # Calculate metrics
        total_entities = len(entities)
        unique_entity_types = len(entity_types_found)
        coverage_percentage = (unique_entity_types / len(evaluator.expected_entities)) * 100
        
        result = {
            'file': pdf_file,
            'text_length': len(text),
            'word_count': len(text.split()),
            'total_entities': total_entities,
            'unique_entity_types': unique_entity_types,
            'coverage_percentage': coverage_percentage,
            'entity_types_found': list(entity_types_found),
            'entities_by_type': dict(entities_by_type),
            'status': status,
            'success': True
        }
        
        results.append(result)
        processing_stats['successful_extractions'] += 1
        processing_stats['total_entities_found'] += total_entities
        
        print(f"  ✅ Success: {total_entities} entities, {unique_entity_types} types ({coverage_percentage:.1f}% coverage)")
        
    except Exception as e:
        print(f"  ❌ Unexpected error: {str(e)}")
        failed_files.append({
            'file': pdf_file,
            'error': str(e),
            'stage': 'unexpected_error'
        })
        processing_stats['failed_extractions'] += 1
        continue
    
    # Progress update setiap 10 file
    if i % 10 == 0:
        success_rate = (processing_stats['successful_extractions'] / i) * 100
        print(f"\n📊 Progress: {i}/{len(pdf_files)} - Success rate: {success_rate:.1f}%\n")

print("\n🎉 PDF processing completed!")
print(f"📊 Processing Statistics:")
print(f"  ✅ Successful extractions: {processing_stats['successful_extractions']}")
print(f"  ❌ Failed extractions: {processing_stats['failed_extractions']}")
print(f"  ⚠️  Empty extractions: {processing_stats['empty_extractions']}")
print(f"  📈 Total entities found: {processing_stats['total_entities_found']}")
# Out:
# 🚀 Starting PDF processing...
#
# [1/100] Processing: zaecf1371060e0ce917e313435323134.pdf
#   📄 Extracted 99782 characters from 32 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 14082 words, 99782 chars
#   🔤 Text has 14082 words
#   📊 Using sliding window strategy
#   ✅ Success: 84 entities, 7 types (35.0% coverage)
# [2/100] Processing: 67791a1f69a102e1ace1cfb512a6c9c8.pdf
#   📄 Extracted 52463 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6330 words, 52463 chars
#   🔤 Text has 6330 words
#   📊 Using sliding window strategy
#   ✅ Success: 28 entities, 7 types (35.0% coverage)
# [3/100] Processing: 14981a64360d15393fd496717bc02bae.pdf
#   📄 Extracted 113887 characters from 30 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 14663 words, 113887 chars
#   🔤 Text has 14663 words
#   📊 Using sliding window strategy
#   ✅ Success: 51 entities, 6 types (30.0% coverage)
# [4/100] Processing: zaed536065ba50ce8d3d313235353030.pdf
#   📄 Extracted 43994 characters from 14 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6242 words, 43994 chars
#   🔤 Text has 6242 words
#   📊 Using sliding window strategy
#   ✅ Success: 33 entities, 7 types (35.0% coverage)
# [5/100] Processing: d58b2248f65017a12df0d3d31a8ebf8b.pdf
#   📄 Extracted 104081 characters from 30 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 13090 words, 104081 chars
#   🔤 Text has 13090 words
#   📊 Using sliding window strategy
#   ✅ Success: 29 entities, 6 types (30.0% coverage)
# [6/100] Processing: c3c13d6d2cef7832e152b5a7ce0f3bab.pdf
#   📄 Extracted 51613 characters from 16 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7164 words, 51613 chars
#   🔤 Text has 7164 words
#   📊 Using sliding window strategy
#   ✅ Success: 60 entities, 8 types (40.0% coverage)
# [7/100] Processing: b9185425ccc94e8f7b0c21e91d274856.pdf
#   📄 Extracted 100444 characters from 35 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 13811 words, 100444 chars
#   🔤 Text has 13811 words
#   📊 Using sliding window strategy
#   ✅ Success: 121 entities, 7 types (35.0% coverage)
# [8/100] Processing: 7b74506a3597a9eed47d4c6402085ee1.pdf
#   📄 Extracted 118340 characters from 38 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 16107 words, 118340 chars
#   🔤 Text has 16107 words
#   📊 Using sliding window strategy
#   ✅ Success: 86 entities, 8 types (40.0% coverage)
# [9/100] Processing: zaed4e8fe341c8aebcd1303935323231.pdf
#   📄 Extracted 45221 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6177 words, 45221 chars
#   🔤 Text has 6177 words
#   📊 Using sliding window strategy
#   ✅ Success: 55 entities, 7 types (35.0% coverage)
# [10/100] Processing: 58d96ea2c959137385768f19c9d95928.pdf
#   📄 Extracted 47430 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6491 words, 47430 chars
#   🔤 Text has 6491 words
#   📊 Using sliding window strategy
#   ✅ Success: 65 entities, 7 types (35.0% coverage)
#
# 📊 Progress: 10/100 - Success rate: 100.0%
#
# [11/100] Processing: zaed16d52d146470895a313134373135.pdf
#   📄 Extracted 67180 characters from 21 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9113 words, 67180 chars
#   🔤 Text has 9113 words
#   📊 Using sliding window strategy
#   ✅ Success: 57 entities, 7 types (35.0% coverage)
# [12/100] Processing: zaf01fed3c738ab2bf28303934373033.pdf
#   📄 Extracted 59931 characters from 19 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8393 words, 59931 chars
#   🔤 Text has 8393 words
#   📊 Using sliding window strategy
#   ✅ Success: 52 entities, 7 types (35.0% coverage)
# [13/100] Processing: zaeff3569a7fa122a565313535373535.pdf
#   📄 Extracted 43106 characters from 14 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6116 words, 43106 chars
#   🔤 Text has 6116 words
#   📊 Using sliding window strategy
#   ✅ Success: 40 entities, 7 types (35.0% coverage)
# [14/100] Processing: zaec9544a09d536a9b41313433373332.pdf
#   📄 Extracted 40464 characters from 13 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5762 words, 40464 chars
#   🔤 Text has 5762 words
#   📊 Using sliding window strategy
#   ✅ Success: 50 entities, 7 types (35.0% coverage)
# [15/100] Processing: 4ac684af7bd54b883608da3bf46de4dc.pdf
#   📄 Extracted 39912 characters from 13 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5478 words, 39912 chars
#   🔤 Text has 5478 words
#   📊 Using sliding window strategy
#   ✅ Success: 40 entities, 7 types (35.0% coverage)
# [16/100] Processing: zaecc6a576052bcc8f07313034343039.pdf
#   📄 Extracted 62548 characters from 20 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8795 words, 62548 chars
#   🔤 Text has 8795 words
#   📊 Using sliding window strategy
#   ✅ Success: 56 entities, 7 types (35.0% coverage)
# [17/100] Processing: zaec27c319453cf0981c303630353433.pdf
#   📄 Extracted 47908 characters from 16 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6565 words, 47908 chars
#   🔤 Text has 6565 words
#   📊 Using sliding window strategy
#   ✅ Success: 56 entities, 7 types (35.0% coverage)
# [18/100] Processing: 1dc948f64f14391cc5c9bae579469d04.pdf
#   📄 Extracted 58980 characters from 16 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6961 words, 58980 chars
#   🔤 Text has 6961 words
#   📊 Using sliding window strategy
#   ✅ Success: 34 entities, 8 types (40.0% coverage)
# [19/100] Processing: 1a7791fb7f6594706b2525b4e6abd661.pdf
#   📄 Extracted 47016 characters from 16 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6618 words, 47016 chars
#   🔤 Text has 6618 words
#   📊 Using sliding window strategy
#   ✅ Success: 40 entities, 7 types (35.0% coverage)
# [20/100] Processing: 4cf6c9c787c48a17345d0c3f880784bf.pdf
#   📄 Extracted 49536 characters from 17 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6821 words, 49536 chars
#   🔤 Text has 6821 words
#   📊 Using sliding window strategy
#   ✅ Success: 40 entities, 7 types (35.0% coverage)
#
# 📊 Progress: 20/100 - Success rate: 100.0%
#
# [21/100] Processing: b603eeacdd1275f4ffa8ff28572ec5e4.pdf
#   📄 Extracted 46042 characters from 16 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5631 words, 46042 chars
#   🔤 Text has 5631 words
#   📊 Using sliding window strategy
#   ✅ Success: 26 entities, 6 types (30.0% coverage)
# [22/100] Processing: bca1a64e5a5d18306041476ced448bf4.pdf
#   📄 Extracted 59179 characters from 17 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7068 words, 59179 chars
#   🔤 Text has 7068 words
#   📊 Using sliding window strategy
#   ✅ Success: 31 entities, 7 types (35.0% coverage)
# [23/100] Processing: zaec7d0041ffc2e0bb4f313732373430.pdf
#   📄 Extracted 33174 characters from 11 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 4729 words, 33174 chars
#   🔤 Text has 4729 words
#   📊 Using sliding window strategy
#   ✅ Success: 33 entities, 7 types (35.0% coverage)
# [24/100] Processing: zaecdbedf71335bc95c3313234363034.pdf
#   📄 Extracted 67030 characters from 22 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9325 words, 67030 chars
#   🔤 Text has 9325 words
#   📊 Using sliding window strategy
#   ✅ Success: 72 entities, 7 types (35.0% coverage)
# [25/100] Processing: 17360939548c9bc33beb2d9138fb721c.pdf
#   📄 Extracted 73028 characters from 27 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8882 words, 73028 chars
#   🔤 Text has 8882 words
#   📊 Using sliding window strategy
#   ✅ Success: 30 entities, 7 types (35.0% coverage)
# [26/100] Processing: zaeca8ef8cdc2554b76b313531383535.pdf
#   📄 Extracted 40502 characters from 14 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5594 words, 40502 chars
#   🔤 Text has 5594 words
#   📊 Using sliding window strategy
#   ✅ Success: 36 entities, 7 types (35.0% coverage)
# [27/100] Processing: acf364c7f81255d3c6d12414e3f59d1f.pdf
#   📄 Extracted 49551 characters from 17 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6721 words, 49551 chars
#   🔤 Text has 6721 words
#   📊 Using sliding window strategy
#   ✅ Success: 56 entities, 8 types (40.0% coverage)
# [28/100] Processing: zaed2f515829519ab54d313533363333.pdf
#   📄 Extracted 37416 characters from 13 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5330 words, 37416 chars
#   🔤 Text has 5330 words
#   📊 Using sliding window strategy
#   ✅ Success: 34 entities, 7 types (35.0% coverage)
# [29/100] Processing: zaecfc03e2c534a88f9a303834333336.pdf
#   📄 Extracted 35865 characters from 12 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5098 words, 35865 chars
#   🔤 Text has 5098 words
#   📊 Using sliding window strategy
#   ✅ Success: 37 entities, 7 types (35.0% coverage)
# [30/100] Processing: zaed29b3d7619a1a8464313230363330.pdf
#   📄 Extracted 44895 characters from 14 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6385 words, 44895 chars
#   🔤 Text has 6385 words
#   📊 Using sliding window strategy
#   ✅ Success: 50 entities, 7 types (35.0% coverage)
#
# 📊 Progress: 30/100 - Success rate: 100.0%
#
# [31/100] Processing: zaefffab8e3d4d549b6b303833363136.pdf
#   📄 Extracted 103793 characters from 32 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 14527 words, 103793 chars
#   🔤 Text has 14527 words
#   📊 Using sliding window strategy
#   ✅ Success: 138 entities, 8 types (40.0% coverage)
# [32/100] Processing: zaec16c6801d8b5c85b1313531373135.pdf
#   📄 Extracted 31635 characters from 10 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 4346 words, 31635 chars
#   🔤 Text has 4346 words
#   📊 Using sliding window strategy
#   ✅ Success: 27 entities, 7 types (35.0% coverage)
# [33/100] Processing: b6134270457a663ebb1aad5004bb61f1.pdf
#   📄 Extracted 61369 characters from 20 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8645 words, 61369 chars
#   🔤 Text has 8645 words
#   📊 Using sliding window strategy
#   ✅ Success: 47 entities, 7 types (35.0% coverage)
# [34/100] Processing: zaec4128a4728e9e87ec313334353335.pdf
#   📄 Extracted 208451 characters from 65 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 29625 words, 208451 chars
#   🔤 Text has 29625 words
#   📊 Using sliding window strategy
#   ✅ Success: 134 entities, 8 types (40.0% coverage)
# [35/100] Processing: zaecc5eb4dcc0cdaaa4c313233313335.pdf
#   📄 Extracted 72115 characters from 23 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 10116 words, 72115 chars
#   🔤 Text has 10116 words
#   📊 Using sliding window strategy
#   ✅ Success: 52 entities, 8 types (40.0% coverage)
# [36/100] Processing: d6ac54fae82fcf6d1da9a577c89b9c71.pdf
#   📄 Extracted 369536 characters from 118 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 53292 words, 369536 chars
#   🔤 Text has 53292 words
#   📊 Using sliding window strategy
#   ✅ Success: 272 entities, 8 types (40.0% coverage)
# [37/100] Processing: zaef97ee7485b48ea027303831333038.pdf
#   📄 Extracted 72913 characters from 23 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9999 words, 72913 chars
#   🔤 Text has 9999 words
#   📊 Using sliding window strategy
#   ✅ Success: 64 entities, 7 types (35.0% coverage)
# [38/100] Processing: 0840279ae7740fc264906da509eb77e0.pdf
#   📄 Extracted 37963 characters from 13 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5305 words, 37963 chars
#   🔤 Text has 5305 words
#   📊 Using sliding window strategy
#   ✅ Success: 48 entities, 7 types (35.0% coverage)
# [39/100] Processing: zaed59831493e3128bb2303831383233.pdf
#   📄 Extracted 71030 characters from 23 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 10366 words, 71030 chars
#   🔤 Text has 10366 words
#   📊 Using sliding window strategy
#   ✅ Success: 57 entities, 8 types (40.0% coverage)
# [40/100] Processing: zaef86e37fe6cc58bb96313534313533.pdf
#   📄 Extracted 65382 characters from 21 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8980 words, 65382 chars
#   🔤 Text has 8980 words
#   📊 Using sliding window strategy
#   ✅ Success: 42 entities, 7 types (35.0% coverage)
#
# 📊 Progress: 40/100 - Success rate: 100.0%
#
# [41/100] Processing: 88c888fcea28fc7d8bf3aec877c3f25c.pdf
#   📄 Extracted 135799 characters from 39 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 16715 words, 135799 chars
#   🔤 Text has 16715 words
#   📊 Using sliding window strategy
#   ✅ Success: 58 entities, 8 types (40.0% coverage)
# [42/100] Processing: zaed24dfa24a1b3ca6ba303833373233.pdf
#   📄 Extracted 46367 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6585 words, 46367 chars
#   🔤 Text has 6585 words
#   📊 Using sliding window strategy
#   ✅ Success: 38 entities, 7 types (35.0% coverage)
# [43/100] Processing: zaeff3569d68f0fa9452313535383030.pdf
#   📄 Extracted 46412 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6338 words, 46412 chars
#   🔤 Text has 6338 words
#   📊 Using sliding window strategy
#   ✅ Success: 67 entities, 7 types (35.0% coverage)
# [44/100] Processing: fb909f5d145d867daab1286cd84732ee.pdf
#   📄 Extracted 55071 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7567 words, 55071 chars
#   🔤 Text has 7567 words
#   📊 Using sliding window strategy
#   ✅ Success: 43 entities, 6 types (30.0% coverage)
# [45/100] Processing: zaefbb73d480545eb36e313330363033.pdf
#   📄 Extracted 54976 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7444 words, 54976 chars
#   🔤 Text has 7444 words
#   📊 Using sliding window strategy
#   ✅ Success: 49 entities, 7 types (35.0% coverage)
# [46/100] Processing: 87c955ff4e1527c36ea6970531c0cdbd.pdf
#   📄 Extracted 31523 characters from 11 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 4275 words, 31523 chars
#   🔤 Text has 4275 words
#   📊 Using sliding window strategy
#   ✅ Success: 44 entities, 7 types (35.0% coverage)
# [47/100] Processing: b527c28155a34ea972fb63aef32ea7dc.pdf
#   📄 Extracted 101120 characters from 30 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 13238 words, 101120 chars
#   🔤 Text has 13238 words
#   📊 Using sliding window strategy
#   ✅ Success: 57 entities, 8 types (40.0% coverage)
# [48/100] Processing: zaed5983162039d88c44303831383236.pdf
#   📄 Extracted 61856 characters from 20 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9014 words, 61856 chars
#   🔤 Text has 9014 words
#   📊 Using sliding window strategy
#   ✅ Success: 68 entities, 8 types (40.0% coverage)
# [49/100] Processing: f87f2e028c1aae1be362722592e4d9a3.pdf
#   📄 Extracted 77505 characters from 19 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9967 words, 77505 chars
#   🔤 Text has 9967 words
#   📊 Using sliding window strategy
#   ✅ Success: 54 entities, 8 types (40.0% coverage)
# [50/100] Processing: zaf00499c307e33a911d313531313239.pdf
#   📄 Extracted 58097 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8120 words, 58097 chars
#   🔤 Text has 8120 words
#   📊 Using sliding window strategy
#   ✅ Success: 73 entities, 7 types (35.0% coverage)
#
# 📊 Progress: 50/100 - Success rate: 100.0%
#
# [51/100] Processing: zaefed9b4dbab5ae84c2303835343335.pdf
#   📄 Extracted 66800 characters from 21 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9213 words, 66800 chars
#   🔤 Text has 9213 words
#   📊 Using sliding window strategy
#   ✅ Success: 67 entities, 8 types (40.0% coverage)
# [52/100] Processing: zaeb5b9047d10fc2bf3c303932383030.pdf
#   📄 Extracted 90778 characters from 30 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 11758 words, 90778 chars
#   🔤 Text has 11758 words
#   📊 Using sliding window strategy
#   ✅ Success: 64 entities, 8 types (40.0% coverage)
# [53/100] Processing: 4f8d5e729788f9e8752e1e325529ff7a.pdf
#   📄 Extracted 120243 characters from 46 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 16575 words, 120243 chars
#   🔤 Text has 16575 words
#   📊 Using sliding window strategy
#   ✅ Success: 127 entities, 7 types (35.0% coverage)
# [54/100] Processing: zaeb44c28a4e36b6b47a303835393439.pdf
#   📄 Extracted 51466 characters from 17 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7111 words, 51466 chars
#   🔤 Text has 7111 words
#   📊 Using sliding window strategy
#   ✅ Success: 45 entities, 7 types (35.0% coverage)
# [55/100] Processing: fc3732e4c9739786a80a074fb3b269b6.pdf
#   📄 Extracted 40618 characters from 14 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5019 words, 40618 chars
#   🔤 Text has 5019 words
#   📊 Using sliding window strategy
#   ✅ Success: 23 entities, 8 types (40.0% coverage)
# [56/100] Processing: zaecdff88d906074ba98313631313536.pdf
#   📄 Extracted 56771 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8057 words, 56771 chars
#   🔤 Text has 8057 words
#   📊 Using sliding window strategy
#   ✅ Success: 48 entities, 7 types (35.0% coverage)
# [57/100] Processing: d01e26b9fc2b534a3046f7925344d2b5.pdf
#   📄 Extracted 52847 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7171 words, 52847 chars
#   🔤 Text has 7171 words
#   📊 Using sliding window strategy
#   ✅ Success: 51 entities, 8 types (40.0% coverage)
# [58/100] Processing: zaef97ee72b9aec6a6fb303831333035.pdf
#   📄 Extracted 57366 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7800 words, 57366 chars
#   🔤 Text has 7800 words
#   📊 Using sliding window strategy
#   ✅ Success: 55 entities, 7 types (35.0% coverage)
# [59/100] Processing: 26f0dd0bcf3bd8cc6436132ebb6491d3.pdf
#   📄 Extracted 48759 characters from 17 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6764 words, 48759 chars
#   🔤 Text has 6764 words
#   📊 Using sliding window strategy
#   ✅ Success: 62 entities, 8 types (40.0% coverage)
# [60/100] Processing: zaed3f9220c3e156976c303830303336.pdf
#   📄 Extracted 43129 characters from 14 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6145 words, 43129 chars
#   🔤 Text has 6145 words
#   📊 Using sliding window strategy
#   ✅ Success: 45 entities, 7 types (35.0% coverage)
#
# 📊 Progress: 60/100 - Success rate: 100.0%
#
# [61/100] Processing: zaec4874ec5957a8affc323033393136.pdf
#   📄 Extracted 50052 characters from 17 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6942 words, 50052 chars
#   🔤 Text has 6942 words
#   📊 Using sliding window strategy
#   ✅ Success: 60 entities, 8 types (40.0% coverage)
# [62/100] Processing: zaec937ebf3bc74c83d5303832383332.pdf
#   📄 Extracted 208145 characters from 63 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 30045 words, 208145 chars
#   🔤 Text has 30045 words
#   📊 Using sliding window strategy
#   ✅ Success: 119 entities, 7 types (35.0% coverage)
# [63/100] Processing: 6d0ea222b47a30b859ffbaf74fbbfa25.pdf
#   📄 Extracted 42464 characters from 14 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5814 words, 42464 chars
#   🔤 Text has 5814 words
#   📊 Using sliding window strategy
#   ✅ Success: 46 entities, 7 types (35.0% coverage)
# [64/100] Processing: zaeb5a2e21d06aec8817313531323534.pdf
#   📄 Extracted 299781 characters from 104 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 41311 words, 299781 chars
#   🔤 Text has 41311 words
#   📊 Using sliding window strategy
#   ✅ Success: 171 entities, 7 types (35.0% coverage)
# [65/100] Processing: 4555d8216f3a859a32a6b79e68ed8c7d.pdf
#   📄 Extracted 34750 characters from 14 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 4778 words, 34750 chars
#   🔤 Text has 4778 words
#   📊 Using sliding window strategy
#   ✅ Success: 53 entities, 7 types (35.0% coverage)
# [66/100] Processing: zaeca365b31731a8b45f313430393333.pdf
#   📄 Extracted 39509 characters from 13 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5663 words, 39509 chars
#   🔤 Text has 5663 words
#   📊 Using sliding window strategy
#   ✅ Success: 40 entities, 7 types (35.0% coverage)
# [67/100] Processing: e656919552433f94a5871a7fc76d35d5.pdf
#   📄 Extracted 221703 characters from 69 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 30777 words, 221703 chars
#   🔤 Text has 30777 words
#   📊 Using sliding window strategy
#   ✅ Success: 160 entities, 8 types (40.0% coverage)
# [68/100] Processing: zaecedcbab11ed6cb577303632353534.pdf
#   📄 Extracted 59863 characters from 20 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8267 words, 59863 chars
#   🔤 Text has 8267 words
#   📊 Using sliding window strategy
#   ✅ Success: 60 entities, 7 types (35.0% coverage)
# [69/100] Processing: zaece6cc71bc183691cd303834333439.pdf
#   📄 Extracted 69671 characters from 23 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9450 words, 69671 chars
#   🔤 Text has 9450 words
#   📊 Using sliding window strategy
#   ✅ Success: 56 entities, 6 types (30.0% coverage)
# [70/100] Processing: zaeb4fedcbdcb676b190313430373131.pdf
#   📄 Extracted 44614 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6462 words, 44614 chars
#   🔤 Text has 6462 words
#   📊 Using sliding window strategy
#   ✅ Success: 53 entities, 8 types (40.0% coverage)
#
# 📊 Progress: 70/100 - Success rate: 100.0%
#
# [71/100] Processing: zaecc06d3314fd94b306313234363138.pdf
#   📄 Extracted 66022 characters from 21 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9357 words, 66022 chars
#   🔤 Text has 9357 words
#   📊 Using sliding window strategy
#   ✅ Success: 60 entities, 7 types (35.0% coverage)
# [72/100] Processing: a56d6e7e73d9cb61ade77c5b41e571b6.pdf
#   📄 Extracted 94670 characters from 38 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 12629 words, 94670 chars
#   🔤 Text has 12629 words
#   📊 Using sliding window strategy
#   ✅ Success: 61 entities, 7 types (35.0% coverage)
# [73/100] Processing: zaed2a8e4a2647e6a673313431303133.pdf
#   📄 Extracted 63261 characters from 20 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8986 words, 63261 chars
#   🔤 Text has 8986 words
#   📊 Using sliding window strategy
#   ✅ Success: 47 entities, 7 types (35.0% coverage)
# [74/100] Processing: 3bb9f9c36075f3c580e95769ca706c2f.pdf
#   📄 Extracted 54326 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7576 words, 54326 chars
#   🔤 Text has 7576 words
#   📊 Using sliding window strategy
#   ✅ Success: 48 entities, 7 types (35.0% coverage)
# [75/100] Processing: 2a32bd17ea9a7e799f117008d893f2f7.pdf
#   📄 Extracted 102286 characters from 39 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 14103 words, 102286 chars
#   🔤 Text has 14103 words
#   📊 Using sliding window strategy
#   ✅ Success: 71 entities, 8 types (40.0% coverage)
# [76/100] Processing: zaed07c56f9c754aba5d303734363438.pdf
#   📄 Extracted 161191 characters from 51 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 23007 words, 161191 chars
#   🔤 Text has 23007 words
#   📊 Using sliding window strategy
#   ✅ Success: 92 entities, 7 types (35.0% coverage)
# [77/100] Processing: b9bc3630645d89eaa6fff26a779a4020.pdf
#   📄 Extracted 51608 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7273 words, 51608 chars
#   🔤 Text has 7273 words
#   📊 Using sliding window strategy
#   ✅ Success: 49 entities, 8 types (40.0% coverage)
# [78/100] Processing: zaed6644b32f2266b215313335343336.pdf
#   📄 Extracted 38078 characters from 13 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 5514 words, 38078 chars
#   🔤 Text has 5514 words
#   📊 Using sliding window strategy
#   ✅ Success: 45 entities, 8 types (40.0% coverage)
# [79/100] Processing: e35041aef668cfdfd91f99ebb1a7aa4d.pdf
#   📄 Extracted 58313 characters from 22 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7147 words, 58313 chars
#   🔤 Text has 7147 words
#   📊 Using sliding window strategy
#   ✅ Success: 30 entities, 6 types (30.0% coverage)
# [80/100] Processing: zaef85de89d8bbc8ade3303833333531.pdf
#   📄 Extracted 57426 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7707 words, 57426 chars
#   🔤 Text has 7707 words
#   📊 Using sliding window strategy
#   ✅ Success: 70 entities, 7 types (35.0% coverage)
#
# 📊 Progress: 80/100 - Success rate: 100.0%
#
# [81/100] Processing: zaefd92a6e0a6ef6b5d5303833363132.pdf
#   📄 Extracted 59509 characters from 19 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 8263 words, 59509 chars
#   🔤 Text has 8263 words
#   📊 Using sliding window strategy
#   ✅ Success: 51 entities, 7 types (35.0% coverage)
# [82/100] Processing: 580a5b1e39be90ec3bc0372509a914f7.pdf
#   📄 Extracted 54563 characters from 17 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7760 words, 54563 chars
#   🔤 Text has 7760 words
#   📊 Using sliding window strategy
#   ✅ Success: 61 entities, 8 types (40.0% coverage)
# [83/100] Processing: zaefa0cbae369d7aba83313435363533.pdf
#   📄 Extracted 82846 characters from 26 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 11422 words, 82846 chars
#   🔤 Text has 11422 words
#   📊 Using sliding window strategy
#   ✅ Success: 55 entities, 7 types (35.0% coverage)
# [84/100] Processing: zaefb1e4682cf5deaf8d303930363433.pdf
#   📄 Extracted 80092 characters from 26 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 11144 words, 80092 chars
#   🔤 Text has 11144 words
#   📊 Using sliding window strategy
#   ✅ Success: 66 entities, 7 types (35.0% coverage)
# [85/100] Processing: zaec42ba5a966910b86f313334313039.pdf
#   📄 Extracted 53950 characters from 18 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7389 words, 53950 chars
#   🔤 Text has 7389 words
#   📊 Using sliding window strategy
#   ✅ Success: 56 entities, 7 types (35.0% coverage)
# [86/100] Processing: zaecf06474015ea2a0bb313334343337.pdf
#   📄 Extracted 46969 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6636 words, 46969 chars
#   🔤 Text has 6636 words
#   📊 Using sliding window strategy
#   ✅ Success: 50 entities, 7 types (35.0% coverage)
# [87/100] Processing: zaeb549ecb72864c8dec313332343135.pdf
#   📄 Extracted 48698 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6794 words, 48698 chars
#   🔤 Text has 6794 words
#   📊 Using sliding window strategy
#   ✅ Success: 58 entities, 7 types (35.0% coverage)
# [88/100] Processing: 8a69e68e827922d7f7a62ca75a143fc7.pdf
#   📄 Extracted 105377 characters from 33 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 14418 words, 105377 chars
#   🔤 Text has 14418 words
#   📊 Using sliding window strategy
#   ✅ Success: 98 entities, 8 types (40.0% coverage)
# [89/100] Processing: zaeb59faeb0286cc9776303930363138.pdf
#   📄 Extracted 66054 characters from 20 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9220 words, 66054 chars
#   🔤 Text has 9220 words
#   📊 Using sliding window strategy
#   ✅ Success: 123 entities, 7 types (35.0% coverage)
# [90/100] Processing: zaeb44c27cedae3e8f94303835393237.pdf
#   📄 Extracted 253569 characters from 79 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 33676 words, 253569 chars
#   🔤 Text has 33676 words
#   📊 Using sliding window strategy
#   ✅ Success: 180 entities, 8 types (40.0% coverage)
#
# 📊 Progress: 90/100 - Success rate: 100.0%
#
# [91/100] Processing: b1492925fb32d728f18a9ed3f93acee7.pdf
#   📄 Extracted 99738 characters from 33 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 12218 words, 99738 chars
#   🔤 Text has 12218 words
#   📊 Using sliding window strategy
#   ✅ Success: 44 entities, 8 types (40.0% coverage)
# [92/100] Processing: zaed0d802d5939f0b6ee313434363038.pdf
#   📄 Extracted 34107 characters from 12 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 4815 words, 34107 chars
#   🔤 Text has 4815 words
#   📊 Using sliding window strategy
#   ✅ Success: 45 entities, 8 types (40.0% coverage)
# [93/100] Processing: d07703ed0cb02ba9fab3368cc1d3c294.pdf
#   📄 Extracted 101311 characters from 33 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 14093 words, 101311 chars
#   🔤 Text has 14093 words
#   📊 Using sliding window strategy
#   ✅ Success: 118 entities, 8 types (40.0% coverage)
# [94/100] Processing: zaefbd2855ab45c4a195313731303430.pdf
#   📄 Extracted 199497 characters from 64 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 27751 words, 199497 chars
#   🔤 Text has 27751 words
#   📊 Using sliding window strategy
#   ✅ Success: 139 entities, 7 types (35.0% coverage)
# [95/100] Processing: zaed1d3f213d248c8b6d313534303439.pdf
#   📄 Extracted 44028 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6224 words, 44028 chars
#   🔤 Text has 6224 words
#   📊 Using sliding window strategy
#   ✅ Success: 50 entities, 7 types (35.0% coverage)
# [96/100] Processing: zaecf8523afd96deabda313535343230.pdf
#   📄 Extracted 49565 characters from 16 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6997 words, 49565 chars
#   🔤 Text has 6997 words
#   📊 Using sliding window strategy
#   ✅ Success: 56 entities, 7 types (35.0% coverage)
# [97/100] Processing: 40c3528749a70021834350a7445317a4.pdf
#   📄 Extracted 47029 characters from 15 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 6485 words, 47029 chars
#   🔤 Text has 6485 words
#   📊 Using sliding window strategy
#   ✅ Success: 45 entities, 8 types (40.0% coverage)
# [98/100] Processing: zaece571937cb18a8c8d313532303531.pdf
#   📄 Extracted 34483 characters from 11 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 4892 words, 34483 chars
#   🔤 Text has 4892 words
#   📊 Using sliding window strategy
#   ✅ Success: 38 entities, 8 types (40.0% coverage)
# [99/100] Processing: zaefb83a83d0c07aac54313033383133.pdf
#   📄 Extracted 73650 characters from 23 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 9995 words, 73650 chars
#   🔤 Text has 9995 words
#   📊 Using sliding window strategy
#   ✅ Success: 62 entities, 7 types (35.0% coverage)
# [100/100] Processing: 99d509c5cabcb77028e8d90006619be6.pdf
#   📄 Extracted 59125 characters from 17 pages
#   📄 Text sample: Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik...
#   📊 Text stats: 7059 words, 59125 chars
#   🔤 Text has 7059 words
#   📊 Using sliding window strategy
#   ✅ Success: 19 entities, 6 types (30.0% coverage)
#
# 📊 Progress: 100/100 - Success rate: 100.0%
#
#
# 🎉 PDF processing completed!
# 📊 Processing Statistics:
#   ✅ Successful extractions: 100
#   ❌ Failed extractions: 0
#   ⚠️  Empty extractions: 0
#   📈 Total entities found: 6306

# %%
# Analisis hasil evaluasi
if results:
    df_results = pd.DataFrame(results)
    
    print("📊 HASIL EVALUASI NER PADA PDF DOCUMENTS")
    print("="*60)
    
    # 1. Statistik Umum
    total_processed = len(df_results)
    success_rate = (total_processed / len(pdf_files)) * 100
    
    print(f"\n1. STATISTIK UMUM:")
    print(f"   📁 Total file diproses: {len(pdf_files)}")
    print(f"   ✅ Berhasil diekstrak: {total_processed} ({success_rate:.1f}%)")
    print(f"   ❌ Gagal diekstrak: {len(failed_files)} ({100-success_rate:.1f}%)")
    
    # 2. Statistik Entity
    avg_entities_per_doc = df_results['total_entities'].mean()
    avg_types_per_doc = df_results['unique_entity_types'].mean()
    avg_coverage = df_results['coverage_percentage'].mean()
    
    print(f"\n2. STATISTIK ENTITY:")
    print(f"   📝 Rata-rata entity per dokumen: {avg_entities_per_doc:.1f}")
    print(f"   🏷️  Rata-rata tipe entity per dokumen: {avg_types_per_doc:.1f}")
    print(f"   📊 Rata-rata coverage entity: {avg_coverage:.1f}%")
    print(f"   🎯 Total entity ditemukan: {df_results['total_entities'].sum()}")
    
    # 3. Distribusi Entity
    print(f"\n3. DISTRIBUSI TIPE ENTITY:")
    for entity_type, count in entity_counter.most_common():
        percentage = (count / df_results['total_entities'].sum()) * 100
        print(f"   {entity_type}: {count} ({percentage:.1f}%)")
    
    # 4. Dokumen dengan performa terbaik dan terburuk
    print(f"\n4. PERFORMA DOKUMEN:")
    best_doc = df_results.loc[df_results['total_entities'].idxmax()]
    worst_doc = df_results.loc[df_results['total_entities'].idxmin()]
    
    print(f"   🏆 Terbaik: {best_doc['file']}")
    print(f"      - {best_doc['total_entities']} entities, {best_doc['coverage_percentage']:.1f}% coverage")
    print(f"   📉 Terburuk: {worst_doc['file']}")
    print(f"      - {worst_doc['total_entities']} entities, {worst_doc['coverage_percentage']:.1f}% coverage")
    
else:
    print("❌ Tidak ada hasil yang berhasil diproses!")
# Out:
# 📊 HASIL EVALUASI NER PADA PDF DOCUMENTS
# ============================================================
#
# 1. STATISTIK UMUM:
#    📁 Total file diproses: 100
#    ✅ Berhasil diekstrak: 100 (100.0%)
#    ❌ Gagal diekstrak: 0 (0.0%)
#
# 2. STATISTIK ENTITY:
#    📝 Rata-rata entity per dokumen: 63.1
#    🏷️  Rata-rata tipe entity per dokumen: 7.2
#    📊 Rata-rata coverage entity: 36.2%
#    🎯 Total entity ditemukan: 6306
#
# 3. DISTRIBUSI TIPE ENTITY:
#    Nomor Putusan: 2302 (36.5%)
#    Melanggar UU (Tuntutan): 1513 (24.0%)
#    Nama Terdakwa: 826 (13.1%)
#    Jenis Perkara: 604 (9.6%)
#    Nama Pengadilan: 493 (7.8%)
#    Tuntutan Hukuman: 340 (5.4%)
#    Nama Pengacara: 127 (2.0%)
#    Tingkat Kasus: 101 (1.6%)
#
# 4. PERFORMA DOKUMEN:
#    🏆 Terbaik: d6ac54fae82fcf6d1da9a577c89b9c71.pdf
#       - 272 entities, 40.0% coverage
#    📉 Terburuk: 99d509c5cabcb77028e8d90006619be6.pdf
#       - 19 entities, 30.0% coverage

# %%
# Analisis file yang gagal
if failed_files:
    print("\n❌ ANALISIS FILE GAGAL")
    print("="*40)
    
    df_failed = pd.DataFrame(failed_files)
    
    # Grup berdasarkan stage error
    error_by_stage = df_failed.groupby('stage').size()
    
    print(f"\nJenis kegagalan:")
    for stage, count in error_by_stage.items():
        percentage = (count / len(failed_files)) * 100
        print(f"  {stage}: {count} files ({percentage:.1f}%)")
    
    print(f"\nDaftar file gagal:")
    for i, failed in enumerate(failed_files[:10], 1):  # Show first 10
        print(f"  {i}. {failed['file']} - {failed['stage']}: {failed['error'][:50]}...")
    
    if len(failed_files) > 10:
        print(f"  ... dan {len(failed_files) - 10} file lainnya")
        
else:
    print("\n✅ Semua file berhasil diproses!")
# Out:
# ✅ Semua file berhasil diproses!

# %%
# Visualisasi hasil
if results:
    plt.style.use('default')
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('Analisis Hasil Evaluasi NER pada PDF Documents', fontsize=16, fontweight='bold')
    
    # 1. Distribusi jumlah entity per dokumen
    axes[0, 0].hist(df_results['total_entities'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
    axes[0, 0].set_title('Distribusi Jumlah Entity per Dokumen')
    axes[0, 0].set_xlabel('Jumlah Entity')
    axes[0, 0].set_ylabel('Jumlah Dokumen')
    axes[0, 0].grid(True, alpha=0.3)
    
    # 2. Distribusi coverage percentage
    axes[0, 1].hist(df_results['coverage_percentage'], bins=20, alpha=0.7, color='lightgreen', edgecolor='black')
    axes[0, 1].set_title('Distribusi Coverage Percentage')
    axes[0, 1].set_xlabel('Coverage Percentage (%)')
    axes[0, 1].set_ylabel('Jumlah Dokumen')
    axes[0, 1].grid(True, alpha=0.3)
    
    # 3. Top 10 entity types
    top_entities = entity_counter.most_common(10)
    entity_names = [item[0] for item in top_entities]
    entity_counts = [item[1] for item in top_entities]
    
    axes[1, 0].barh(range(len(entity_names)), entity_counts, color='coral')
    axes[1, 0].set_yticks(range(len(entity_names)))
    axes[1, 0].set_yticklabels([name[:20] + '...' if len(name) > 20 else name for name in entity_names])
    axes[1, 0].set_title('Top 10 Entity Types Ditemukan')
    axes[1, 0].set_xlabel('Jumlah')
    axes[1, 0].grid(True, alpha=0.3)
    
    # 4. Success vs Failure rate
    success_count = len(results)
    failure_count = len(failed_files)
    
    labels = ['Berhasil', 'Gagal']
    sizes = [success_count, failure_count]
    colors = ['lightgreen', 'lightcoral']
    
    axes[1, 1].pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
    axes[1, 1].set_title('Success vs Failure Rate')
    
    plt.tight_layout()
    plt.show()
    
    # Visualisasi tambahan: Entity types coverage
    plt.figure(figsize=(12, 8))
    
    # Hitung berapa dokumen yang mengandung setiap entity type
    entity_doc_count = {}
    for entity_type in evaluator.expected_entities:
        count = sum(1 for result in results if entity_type in result['entity_types_found'])
        entity_doc_count[entity_type] = count
    
    # Sort berdasarkan count
    sorted_entities = sorted(entity_doc_count.items(), key=lambda x: x[1], reverse=True)
    entity_names = [item[0] for item in sorted_entities]
    doc_counts = [item[1] for item in sorted_entities]
    percentages = [(count / len(results)) * 100 for count in doc_counts]
    
    plt.barh(range(len(entity_names)), percentages, color='steelblue')
    plt.yticks(range(len(entity_names)), [name[:25] + '...' if len(name) > 25 else name for name in entity_names])
    plt.xlabel('Persentase Dokumen yang Mengandung Entity (%)')
    plt.title('Coverage Entity Types Across All Documents')
    plt.grid(True, alpha=0.3)
    
    # Add value labels
    for i, (count, pct) in enumerate(zip(doc_counts, percentages)):
        plt.text(pct + 1, i, f'{count} docs ({pct:.1f}%)', va='center')
    
    plt.tight_layout()
    plt.show()
    
else:
    print("❌ Tidak ada data untuk divisualisasikan")

# %%
# Simpan hasil evaluasi ke file
if results:
    # Simpan hasil detail
    output_dir = "results"
    os.makedirs(output_dir, exist_ok=True)
    
    # 1. Simpan hasil evaluasi detail
    results_file = os.path.join(output_dir, "pdf_ner_evaluation_results.json")
    with open(results_file, 'w', encoding='utf-8') as f:
        json.dump({
            'evaluation_summary': {
                'total_files_processed': len(pdf_files),
                'successful_extractions': len(results),
                'failed_extractions': len(failed_files),
                'success_rate_percentage': (len(results) / len(pdf_files)) * 100,
                'average_entities_per_document': float(df_results['total_entities'].mean()),
                'average_entity_types_per_document': float(df_results['unique_entity_types'].mean()),
                'average_coverage_percentage': float(df_results['coverage_percentage'].mean()),
                'total_entities_found': int(df_results['total_entities'].sum()),
                'entity_distribution': dict(entity_counter)
            },
            'detailed_results': results,
            'failed_files': failed_files
        }, f, indent=2, ensure_ascii=False)
    
    # 2. Simpan summary ke CSV
    summary_file = os.path.join(output_dir, "pdf_ner_evaluation_summary.csv")
    df_results[['file', 'total_entities', 'unique_entity_types', 'coverage_percentage', 'word_count']].to_csv(
        summary_file, index=False, encoding='utf-8'
    )
    
    # 3. Simpan entity distribution
    entity_dist_file = os.path.join(output_dir, "entity_distribution.csv")
    entity_df = pd.DataFrame([
        {'entity_type': entity_type, 'count': count, 'percentage': (count / df_results['total_entities'].sum()) * 100}
        for entity_type, count in entity_counter.most_common()
    ])
    entity_df.to_csv(entity_dist_file, index=False, encoding='utf-8')
    
    print(f"\n💾 Hasil evaluasi disimpan:")
    print(f"   📄 Detail results: {results_file}")
    print(f"   📊 Summary CSV: {summary_file}")
    print(f"   📈 Entity distribution: {entity_dist_file}")
    
else:
    print("❌ Tidak ada hasil untuk disimpan")
# Out:
# 💾 Hasil evaluasi disimpan:
#    📄 Detail results: results\pdf_ner_evaluation_results.json
#    📊 Summary CSV: results\pdf_ner_evaluation_summary.csv
#    📈 Entity distribution: results\entity_distribution.csv

# %%
# Final Summary Report
print("\n" + "="*80)
print("🏁 LAPORAN AKHIR EVALUASI NER PADA PDF DOCUMENTS")
print("="*80)

if results:
    success_rate = (len(results) / len(pdf_files)) * 100
    avg_entities = df_results['total_entities'].mean()
    avg_coverage = df_results['coverage_percentage'].mean()
    
    print(f"\n📊 RINGKASAN KINERJA:")
    print(f"   🎯 Success Rate: {success_rate:.1f}% ({len(results)}/{len(pdf_files)} dokumen)")
    print(f"   📝 Rata-rata Entity per Dokumen: {avg_entities:.1f}")
    print(f"   📊 Rata-rata Coverage: {avg_coverage:.1f}%")
    print(f"   🏷️  Total Entity Ditemukan: {df_results['total_entities'].sum()}")
    
    print(f"\n🔍 ANALISIS KUALITAS:")
    high_performance_docs = len(df_results[df_results['coverage_percentage'] >= 50])
    medium_performance_docs = len(df_results[(df_results['coverage_percentage'] >= 25) & (df_results['coverage_percentage'] < 50)])
    low_performance_docs = len(df_results[df_results['coverage_percentage'] < 25])
    
    print(f"   🟢 High Performance (≥50% coverage): {high_performance_docs} dokumen ({(high_performance_docs/len(results)*100):.1f}%)")
    print(f"   🟡 Medium Performance (25-50% coverage): {medium_performance_docs} dokumen ({(medium_performance_docs/len(results)*100):.1f}%)")
    print(f"   🔴 Low Performance (<25% coverage): {low_performance_docs} dokumen ({(low_performance_docs/len(results)*100):.1f}%)")
    
    print(f"\n💡 REKOMENDASI:")
    if success_rate >= 90:
        print(f"   ✅ Model menunjukkan performa yang sangat baik")
    elif success_rate >= 70:
        print(f"   ⚠️  Model menunjukkan performa yang baik, namun perlu perbaikan")
    else:
        print(f"   ❌ Model perlu perbaikan signifikan")
    
    if avg_coverage < 30:
        print(f"   📈 Perlu meningkatkan coverage entity types")
    
    if len(failed_files) > 0:
        print(f"   🔧 Perlu perbaikan preprocessing untuk mengurangi failure rate")
        
else:
    print(f"\n❌ EVALUASI GAGAL:")
    print(f"   Tidak ada dokumen yang berhasil diproses")
    print(f"   Total kegagalan: {len(failed_files)} dari {len(pdf_files)} dokumen")

print("\n" + "="*80)
print("📋 Evaluasi selesai! Periksa folder 'results' untuk detail lengkap.")
print("="*80)
# Out:
# ================================================================================
# 🏁 LAPORAN AKHIR EVALUASI NER PADA PDF DOCUMENTS
# ================================================================================
#
# 📊 RINGKASAN KINERJA:
#    🎯 Success Rate: 100.0% (100/100 dokumen)
#    📝 Rata-rata Entity per Dokumen: 63.1
#    📊 Rata-rata Coverage: 36.2%
#    🏷️  Total Entity Ditemukan: 6306
#
# 🔍 ANALISIS KUALITAS:
#    🟢 High Performance (≥50% coverage): 0 dokumen (0.0%)
#    🟡 Medium Performance (25-50% coverage): 100 dokumen (100.0%)
#    🔴 Low Performance (<25% coverage): 0 dokumen (0.0%)
#
# 💡 REKOMENDASI:
#    ✅ Model menunjukkan performa yang sangat baik
#
# ================================================================================
# 📋 Evaluasi selesai! Periksa folder 'results' untuk detail lengkap.
# ================================================================================

# %%
# Diagnostic Analysis: Why are some entities missing?
print("🔍 ANALISIS DIAGNOSTIK: Entity yang Tidak Ditemukan")
print("="*60)

# Check which entities are completely missing
all_found_entities = set()
for result in results:
    all_found_entities.update(result['entity_types_found'])

missing_entities = set(evaluator.expected_entities) - all_found_entities
found_entities = set(evaluator.expected_entities) & all_found_entities

print(f"\n📊 Summary:")
print(f"   ✅ Entity types found: {len(found_entities)}/20 ({len(found_entities)/20*100:.1f}%)")
print(f"   ❌ Entity types missing: {len(missing_entities)}/20 ({len(missing_entities)/20*100:.1f}%)")

print(f"\n✅ Entity types yang DITEMUKAN:")
for entity in sorted(found_entities):
    count = entity_counter[entity]
    avg_per_doc = count / len(results)
    docs_with_entity = sum(1 for result in results if entity in result['entity_types_found'])
    print(f"   • {entity}: {count} instances ({avg_per_doc:.1f}/doc) in {docs_with_entity} docs ({docs_with_entity/len(results)*100:.1f}%)")

print(f"\n❌ Entity types yang TIDAK DITEMUKAN:")
for entity in sorted(missing_entities):
    print(f"   • {entity}: 0 instances (0% coverage)")

# Sample text analysis
print(f"\n📄 SAMPLE TEXT ANALYSIS:")
print("Analyzing first successful document for entity patterns...")

if results:
    sample_result = results[0]
    sample_file = sample_result['file']
    sample_path = os.path.join(PDF_FOLDER, sample_file)
    
    # Re-extract text for analysis
    sample_text = evaluator.extract_text_from_pdf(sample_path)
    sample_words = sample_text.split()
    
    print(f"\nSample file: {sample_file}")
    print(f"Text length: {len(sample_text)} chars, {len(sample_words)} words")
    print(f"Entities found: {sample_result['total_entities']}")
    print(f"Entity types: {sample_result['entity_types_found']}")
    
    # Show text sample
    print(f"\nFirst 200 words of text:")
    print(' '.join(sample_words[:200]) + "...")
    
    # Look for potential patterns that might contain missing entities
    print(f"\n🔍 Looking for potential date patterns:")
    import re
    date_patterns = re.findall(r'\d{1,2}[-/]\d{1,2}[-/]\d{2,4}|\d{1,2}\s+\w+\s+\d{4}', sample_text)
    if date_patterns:
        print(f"   Found date-like patterns: {date_patterns[:5]}")
    else:
        print("   No obvious date patterns found")
    
    print(f"\n🔍 Looking for potential court/legal terms:")
    legal_terms = ['pengadilan', 'hakim', 'jaksa', 'terdakwa', 'putusan', 'dakwaan', 'pasal']
    found_terms = []
    for term in legal_terms:
        if term.lower() in sample_text.lower():
            found_terms.append(term)
    
    if found_terms:
        print(f"   Found legal terms: {found_terms}")
    else:
        print("   No obvious legal terms found")

print(f"\n💡 INSIGHTS:")
print(f"   • Model berhasil mengekstrak {len(found_entities)} dari 20 jenis entity yang diharapkan")
print(f"   • Entity yang paling sering ditemukan: Nomor Putusan, Nama Pengacara, Nama Terdakwa")
print(f"   • Entity yang tidak ditemukan mungkin jarang muncul dalam dokumen atau")
print(f"     memiliki format yang tidak dikenali oleh model")
print(f"   • Perlu analisis lebih lanjut pada dokumen yang mengandung entity yang hilang")
# Out:
# 🔍 ANALISIS DIAGNOSTIK: Entity yang Tidak Ditemukan
# ============================================================
#
# 📊 Summary:
#    ✅ Entity types found: 8/20 (40.0%)
#    ❌ Entity types missing: 12/20 (60.0%)
#
# ✅ Entity types yang DITEMUKAN:
#    • Jenis Perkara: 604 instances (6.0/doc) in 95 docs (95.0%)
#    • Melanggar UU (Tuntutan): 1513 instances (15.1/doc) in 100 docs (100.0%)
#    • Nama Pengacara: 127 instances (1.3/doc) in 33 docs (33.0%)
#    • Nama Pengadilan: 493 instances (4.9/doc) in 100 docs (100.0%)
#    • Nama Terdakwa: 826 instances (8.3/doc) in 99 docs (99.0%)
#    • Nomor Putusan: 2302 instances (23.0/doc) in 100 docs (100.0%)
#    • Tingkat Kasus: 101 instances (1.0/doc) in 99 docs (99.0%)
#    • Tuntutan Hukuman: 340 instances (3.4/doc) in 99 docs (99.0%)
#
# ❌ Entity types yang TIDAK DITEMUKAN:
#    • Jenis Amar: 0 instances (0% coverage)
#    • Jenis Dakwaan: 0 instances (0% coverage)
#    • Melanggar UU (Dakwaan): 0 instances (0% coverage)
#    • Melanggar UU (Pertimbangan Hukum): 0 instances (0% coverage)
#    • Nama Hakim Anggota: 0 instances (0% coverage)
#    • Nama Hakim Ketua: 0 instances (0% coverage)
#    • Nama Jaksa: 0 instances (0% coverage)
#    • Nama Panitera: 0 instances (0% coverage)
#    • Nama Saksi: 0 instances (0% coverage)
#    • Putusan Hukuman: 0 instances (0% coverage)
#    • Tanggal Kejadian: 0 instances (0% coverage)
#    • Tanggal Putusan: 0 instances (0% coverage)
#
# 📄 SAMPLE TEXT ANALYSIS:
# Analyzing first successful document for entity patterns...
#   📄 Extracted 99782 characters from 32 pages
#
# Sample file: zaecf1371060e0ce917e313435323134.pdf
# Text length: 99782 chars, 14082 words
# Entities found: 84
# Entity types: ['Nama Terdakwa', 'Nama Pengadilan', 'Tingkat Kasus', 'Jenis Perkara', 'Tuntutan Hukuman', 'Melanggar UU (Tuntutan)', 'Nomor Putusan']
#
# First 200 words of text:
# Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Mahkamah Agung Republik Indonesia Direktori Putusan Mahkamah Agung Republik Indonesia putusan.mahkamahagung.go.id P U T U S A N Nomor 106/Pid.B/2022/PN Bkl DEMI KEADILAN BERDASARKAN KETUHANAN YANG MAHA ESA Pengadilan Negeri Bangkalan yang mengadili perkara pidana dengan acara pemeriksaan biasa dalam tingkat pertama menjatuhkan putusan sebagai berikut dalam perkara Terdakwa : Nama lengkap :YANTO BIN MAT BAKRI ; T empat lahir :Bangkalan; Umur/tanggal lahir :27 Tahun / 01 Juli 1994 ; Jenis Kelamin :Laki-laki; Kebangsaan :Indonesia; T empat tinggal :Dsn. Lantek Tengah Ds. Lantek Barat Kec. Galis Kab. Bangkalan; Agama :Islam; Pekerjaan :Tidak Bekerja; T erdakwa ditangkap berdasarkan surat perintah penangkapan Nomor Sprin- Kap/29/II/RES.1.8/2022, tanggal 28 Februari 2022 dan ditahan dalam tahanan Rutan oleh : 1. Penyidik sejak tanggal 01 Maret 2022 sampai dengan tanggal 20 Maret 2022; 2. Penyidik Perpanjangan Oleh PU sejak tanggal 21 Maret 2022 sampai dengan tanggal 29 April 2022; 3. Penuntut sejak tanggal 20 April 2022 sampai dengan tanggal 09 Mei 2022; 4. Hakim PN sejak tanggal 25 April 2022 sampai dengan tanggal 24 Mei 2022; 5. Hakim PN Perpanjangan Pertama Oleh Ketua PN sejak tanggal 25 Mei 2022 sampai...
#
# 🔍 Looking for potential date patterns:
#    Found date-like patterns: ['01 Juli 1994', '28 Februari 2022', '01 Maret 2022', '20 Maret 2022', '21 Maret 2022']
#
# 🔍 Looking for potential court/legal terms:
#    Found legal terms: ['pengadilan', 'hakim', 'jaksa', 'terdakwa', 'putusan', 'dakwaan', 'pasal']
#
# 💡 INSIGHTS:
#    • Model berhasil mengekstrak 8 dari 20 jenis entity yang diharapkan
#    • Entity yang paling sering ditemukan: Nomor Putusan, Nama Pengacara, Nama Terdakwa
#    • Entity yang tidak ditemukan mungkin jarang muncul dalam dokumen atau
#      memiliki format yang tidak dikenali oleh model
#    • Perlu analisis lebih lanjut pada dokumen yang mengandung entity yang hilang
