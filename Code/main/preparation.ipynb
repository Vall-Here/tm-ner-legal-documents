# %%
# Install required packages if not already installed
# !pip install transformers torch

from transformers import AutoTokenizer
import torch
import numpy as np
from typing import List, Tuple

# Initialize BERT tokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
print("Tokenizer loaded successfully!")
print(f"Max model input size: {tokenizer.model_max_length}")
print(f"Special tokens: {tokenizer.special_tokens_map}")
# Out:
# Tokenizer loaded successfully!
# Max model input size: 512
# Special tokens: {'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}

# %%
# Install required packages for NER implementation
# !pip install transformers torch scikit-learn seqeval pandas numpy matplotlib seaborn tqdm
# !pip install datasets accelerate

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
main_df = pd.read_csv('../../Datasets/FINAL/DATASET_BERT_SENTENCE.csv')
main_df
# Out:
#                                                   text  \
# 0    PUTUSAN Nomor 192/Pid. B/2019/PN Bkl DEMI KEAD...
# 1    PUTUSAN Nomor 9/Pid. B/2019/PN Bkl DEMI KEADIL...
# 2    PUTUSAN Nomor 108/Pid. B/2020/PN Bkl DEMI KEAD...
# 3    PUTUSAN NOMOR : 294/Pid. B/2018/PN. BKL. DEMI ...
# 4    PUTUSAN Nomor 431/Pid. B/2018/PN Bkl DEMI KEAD...
# ..                                                 ...
# 230  PUTUSAN Nomor 31/Pid. B/2025/PN Bkl DEMI KEADI...
# 231  PUTUSAN Nomor 47/Pid. B/2025/PN Bkl DEMI KEADI...
# 232  PUTUSAN Nomor 76/Pid. B/2025/PN Bkl DEMI KEADI...
# 233  PUTUSAN Nomor 77/Pid. B/2025/PN Bkl DEMI KEADI...
# 234  Nomor 60/Pid. B/2025/PN Bkl DEMI KEADILAN BERD...
#
#                                                 labels
# 0    O O B_VERN I_VERN I_VERN O O O O O O O O O O O...
# 1    O O B_VERN I_VERN I_VERN O O O O O O O O O O O...
# 2    O O B_VERN I_VERN I_VERN O O O O O O O O O O O...
# 3    O O O B_VERN I_VERN I_VERN O O O O O O O O O O...
# 4    O O O O O O O O O O O O O O O O O O O O O O O ...
# ..                                                 ...
# 230  O O B_VERN I_VERN I_VERN O O O O O O O O O O O...
# 231  O O B_VERN I_VERN I_VERN O O O O O O O O O O O...
# 232  O O O O O O O O O O O O O O O O O O O O O O O ...
# 233  O O B_VERN I_VERN I_VERN O O O O O O O O O O O...
# 234  O B_VERN I_VERN I_VERN O O O O O O O O O O O O...
#
# [235 rows x 2 columns]

# %%
def tokenize_and_chunk_text(text: str, labels: str, max_length: int = 512, overlap: int = 50) -> List[Tuple[str, str]]:

    # Split text and labels into tokens/words
    words = text.split()
    label_list = labels.split()
    
    # Ensure words and labels have the same length
    if len(words) != len(label_list):
        print(f"Warning: Mismatch between words ({len(words)}) and labels ({len(label_list)})")
        # Truncate to minimum length to avoid index errors
        min_len = min(len(words), len(label_list))
        words = words[:min_len]
        label_list = label_list[:min_len]
    
    chunks = []
    
    # Calculate effective max length (accounting for special tokens [CLS], [SEP])
    # Use even more conservative estimate to ensure we stay under 512 tokens
    effective_max_length = max_length // 4  # Very conservative: assume ~4 tokens per word
    
    start_idx = 0
    while start_idx < len(words):
        # Calculate end index for current chunk
        end_idx = min(start_idx + effective_max_length, len(words))
        
        # Extract chunk
        chunk_words = words[start_idx:end_idx]
        chunk_labels = label_list[start_idx:end_idx]
        
        # Convert back to strings
        chunk_text = ' '.join(chunk_words)
        chunk_labels_str = ' '.join(chunk_labels)
        
        chunks.append((chunk_text, chunk_labels_str))
        
        # Move to next chunk with overlap
        if end_idx >= len(words):
            break
        start_idx = end_idx - overlap
        
        # Ensure we don't go backwards
        if start_idx <= 0:
            start_idx = end_idx
    
    return chunks

def validate_chunk_tokens(text: str, max_length: int = 512) -> Tuple[int, bool]:

    # Tokenize the text
    tokens = tokenizer.encode(text, add_special_tokens=True, truncation=False)
    token_count = len(tokens)
    is_valid = token_count <= max_length
    
    return token_count, is_valid

# %%
# Test the chunking function on a sample
print("Testing tokenization and chunking on sample data:")
print("=" * 50)

# Get a sample with long text
sample_idx = main_df['text'].str.len().idxmax()
sample_text = main_df.iloc[sample_idx]['text']
sample_labels = main_df.iloc[sample_idx]['labels']

print(f"Original text length: {len(sample_text)} characters")
print(f"Original word count: {len(sample_text.split())} words")

# Check original token count
original_tokens, is_valid = validate_chunk_tokens(sample_text)
print(f"Original token count: {original_tokens} (Valid: {is_valid})")

# Chunk the text
chunks = tokenize_and_chunk_text(sample_text, sample_labels, max_length=512, overlap=50)
print(f"\nNumber of chunks created: {len(chunks)}")

# Validate each chunk
print("\nChunk validation:")
for i, (chunk_text, chunk_labels) in enumerate(chunks):
    token_count, is_valid = validate_chunk_tokens(chunk_text)
    word_count = len(chunk_text.split())
    print(f"Chunk {i+1}: {word_count} words, {token_count} tokens (Valid: {is_valid})")
    
    if i == 0:  # Show first chunk as example
        print(f"  First chunk preview: {chunk_text[:200]}...")
        print(f"  First chunk labels: {chunk_labels[:200]}...")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (65679 > 512). Running this sequence through the model will result in indexing errors
# Testing tokenization and chunking on sample data:
# ==================================================
# Original text length: 176599 characters
# Original word count: 26277 words
# Original token count: 65679 (Valid: False)
#
# Number of chunks created: 337
#
# Chunk validation:
# Chunk 1: 128 words, 305 tokens (Valid: True)
#   First chunk preview: PUTUSAN Nomor 48/Pid. B/2023/PN Bkl DEMI KEADILAN BERDASARKAN KETUHANAN YANG MAHA ESA Pengadilan Negeri Bangkalan yang mengadili perkara pidana dengan acara pemeriksaan biasa dalam tingkat pertama men...
#   First chunk labels: O O B_VERN I_VERN I_VERN O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B_DEFN I_DEFN I_DEFN I_DEFN O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O...
# Chunk 2: 128 words, 285 tokens (Valid: True)
# Chunk 3: 128 words, 279 tokens (Valid: True)
# Chunk 4: 128 words, 318 tokens (Valid: True)
# Chunk 5: 128 words, 337 tokens (Valid: True)
# Chunk 6: 128 words, 303 tokens (Valid: True)
# Chunk 7: 128 words, 286 tokens (Valid: True)
# Chunk 8: 128 words, 308 tokens (Valid: True)
# Chunk 9: 128 words, 335 tokens (Valid: True)
# Chunk 10: 128 words, 343 tokens (Valid: True)
# Chunk 11: 128 words, 313 tokens (Valid: True)
# Chunk 12: 128 words, 302 tokens (Valid: True)
# Chunk 13: 128 words, 327 tokens (Valid: True)
# Chunk 14: 128 words, 311 tokens (Valid: True)
# Chunk 15: 128 words, 309 tokens (Valid: True)
# Chunk 16: 128 words, 325 tokens (Valid: True)
# Chunk 17: 128 words, 333 tokens (Valid: True)
# Chunk 18: 128 words, 334 tokens (Valid: True)
# Chunk 19: 128 words, 342 tokens (Valid: True)
# Chunk 20: 128 words, 342 tokens (Valid: True)
# Chunk 21: 128 words, 327 tokens (Valid: True)
# Chunk 22: 128 words, 335 tokens (Valid: True)
# Chunk 23: 128 words, 344 tokens (Valid: True)
# Chunk 24: 128 words, 340 tokens (Valid: True)
# Chunk 25: 128 words, 336 tokens (Valid: True)
# Chunk 26: 128 words, 326 tokens (Valid: True)
# Chunk 27: 128 words, 319 tokens (Valid: True)
# Chunk 28: 128 words, 315 tokens (Valid: True)
# Chunk 29: 128 words, 333 tokens (Valid: True)
# Chunk 30: 128 words, 335 tokens (Valid: True)
# Chunk 31: 128 words, 328 tokens (Valid: True)
# Chunk 32: 128 words, 344 tokens (Valid: True)
# Chunk 33: 128 words, 288 tokens (Valid: True)
# Chunk 34: 128 words, 286 tokens (Valid: True)
# Chunk 35: 128 words, 291 tokens (Valid: True)
# Chunk 36: 128 words, 320 tokens (Valid: True)
# Chunk 37: 128 words, 333 tokens (Valid: True)
# Chunk 38: 128 words, 332 tokens (Valid: True)
# Chunk 39: 128 words, 333 tokens (Valid: True)
# Chunk 40: 128 words, 328 tokens (Valid: True)
# Chunk 41: 128 words, 324 tokens (Valid: True)
# Chunk 42: 128 words, 315 tokens (Valid: True)
# Chunk 43: 128 words, 343 tokens (Valid: True)
# Chunk 44: 128 words, 360 tokens (Valid: True)
# Chunk 45: 128 words, 364 tokens (Valid: True)
# Chunk 46: 128 words, 362 tokens (Valid: True)
# Chunk 47: 128 words, 303 tokens (Valid: True)
# Chunk 48: 128 words, 262 tokens (Valid: True)
# Chunk 49: 128 words, 307 tokens (Valid: True)
# Chunk 50: 128 words, 332 tokens (Valid: True)
# Chunk 51: 128 words, 322 tokens (Valid: True)
# Chunk 52: 128 words, 312 tokens (Valid: True)
# Chunk 53: 128 words, 304 tokens (Valid: True)
# Chunk 54: 128 words, 328 tokens (Valid: True)
# Chunk 55: 128 words, 327 tokens (Valid: True)
# Chunk 56: 128 words, 328 tokens (Valid: True)
# Chunk 57: 128 words, 334 tokens (Valid: True)
# Chunk 58: 128 words, 343 tokens (Valid: True)
# Chunk 59: 128 words, 333 tokens (Valid: True)
# Chunk 60: 128 words, 325 tokens (Valid: True)
# Chunk 61: 128 words, 338 tokens (Valid: True)
# Chunk 62: 128 words, 338 tokens (Valid: True)
# Chunk 63: 128 words, 343 tokens (Valid: True)
# Chunk 64: 128 words, 334 tokens (Valid: True)
# Chunk 65: 128 words, 331 tokens (Valid: True)
# Chunk 66: 128 words, 309 tokens (Valid: True)
# Chunk 67: 128 words, 312 tokens (Valid: True)
# Chunk 68: 128 words, 337 tokens (Valid: True)
# Chunk 69: 128 words, 336 tokens (Valid: True)
# Chunk 70: 128 words, 338 tokens (Valid: True)
# Chunk 71: 128 words, 312 tokens (Valid: True)
# Chunk 72: 128 words, 293 tokens (Valid: True)
# Chunk 73: 128 words, 295 tokens (Valid: True)
# Chunk 74: 128 words, 294 tokens (Valid: True)
# Chunk 75: 128 words, 322 tokens (Valid: True)
# Chunk 76: 128 words, 336 tokens (Valid: True)
# Chunk 77: 128 words, 335 tokens (Valid: True)
# Chunk 78: 128 words, 321 tokens (Valid: True)
# Chunk 79: 128 words, 332 tokens (Valid: True)
# Chunk 80: 128 words, 316 tokens (Valid: True)
# Chunk 81: 128 words, 331 tokens (Valid: True)
# Chunk 82: 128 words, 349 tokens (Valid: True)
# Chunk 83: 128 words, 362 tokens (Valid: True)
# Chunk 84: 128 words, 377 tokens (Valid: True)
# Chunk 85: 128 words, 344 tokens (Valid: True)
# Chunk 86: 128 words, 267 tokens (Valid: True)
# Chunk 87: 128 words, 284 tokens (Valid: True)
# Chunk 88: 128 words, 315 tokens (Valid: True)
# Chunk 89: 128 words, 323 tokens (Valid: True)
# Chunk 90: 128 words, 308 tokens (Valid: True)
# Chunk 91: 128 words, 314 tokens (Valid: True)
# Chunk 92: 128 words, 328 tokens (Valid: True)
# Chunk 93: 128 words, 325 tokens (Valid: True)
# Chunk 94: 128 words, 332 tokens (Valid: True)
# Chunk 95: 128 words, 344 tokens (Valid: True)
# Chunk 96: 128 words, 327 tokens (Valid: True)
# Chunk 97: 128 words, 323 tokens (Valid: True)
# Chunk 98: 128 words, 338 tokens (Valid: True)
# Chunk 99: 128 words, 340 tokens (Valid: True)
# Chunk 100: 128 words, 343 tokens (Valid: True)
# Chunk 101: 128 words, 338 tokens (Valid: True)
# Chunk 102: 128 words, 322 tokens (Valid: True)
# Chunk 103: 128 words, 314 tokens (Valid: True)
# Chunk 104: 128 words, 310 tokens (Valid: True)
# Chunk 105: 128 words, 336 tokens (Valid: True)
# Chunk 106: 128 words, 330 tokens (Valid: True)
# Chunk 107: 128 words, 338 tokens (Valid: True)
# Chunk 108: 128 words, 322 tokens (Valid: True)
# Chunk 109: 128 words, 285 tokens (Valid: True)
# Chunk 110: 128 words, 294 tokens (Valid: True)
# Chunk 111: 128 words, 283 tokens (Valid: True)
# Chunk 112: 128 words, 314 tokens (Valid: True)
# Chunk 113: 128 words, 328 tokens (Valid: True)
# Chunk 114: 128 words, 336 tokens (Valid: True)
# Chunk 115: 128 words, 332 tokens (Valid: True)
# Chunk 116: 128 words, 328 tokens (Valid: True)
# Chunk 117: 128 words, 325 tokens (Valid: True)
# Chunk 118: 128 words, 311 tokens (Valid: True)
# Chunk 119: 128 words, 344 tokens (Valid: True)
# Chunk 120: 128 words, 354 tokens (Valid: True)
# Chunk 121: 128 words, 365 tokens (Valid: True)
# Chunk 122: 128 words, 369 tokens (Valid: True)
# Chunk 123: 128 words, 331 tokens (Valid: True)
# Chunk 124: 128 words, 321 tokens (Valid: True)
# Chunk 125: 128 words, 305 tokens (Valid: True)
# Chunk 126: 128 words, 311 tokens (Valid: True)
# Chunk 127: 128 words, 307 tokens (Valid: True)
# Chunk 128: 128 words, 280 tokens (Valid: True)
# Chunk 129: 128 words, 303 tokens (Valid: True)
# Chunk 130: 128 words, 321 tokens (Valid: True)
# Chunk 131: 128 words, 361 tokens (Valid: True)
# Chunk 132: 128 words, 352 tokens (Valid: True)
# Chunk 133: 128 words, 289 tokens (Valid: True)
# Chunk 134: 128 words, 306 tokens (Valid: True)
# Chunk 135: 128 words, 315 tokens (Valid: True)
# Chunk 136: 128 words, 293 tokens (Valid: True)
# Chunk 137: 128 words, 299 tokens (Valid: True)
# Chunk 138: 128 words, 312 tokens (Valid: True)
# Chunk 139: 128 words, 306 tokens (Valid: True)
# Chunk 140: 128 words, 301 tokens (Valid: True)
# Chunk 141: 128 words, 316 tokens (Valid: True)
# Chunk 142: 128 words, 335 tokens (Valid: True)
# Chunk 143: 128 words, 343 tokens (Valid: True)
# Chunk 144: 128 words, 339 tokens (Valid: True)
# Chunk 145: 128 words, 330 tokens (Valid: True)
# Chunk 146: 128 words, 320 tokens (Valid: True)
# Chunk 147: 128 words, 338 tokens (Valid: True)
# Chunk 148: 128 words, 342 tokens (Valid: True)
# Chunk 149: 128 words, 344 tokens (Valid: True)
# Chunk 150: 128 words, 322 tokens (Valid: True)
# Chunk 151: 128 words, 316 tokens (Valid: True)
# Chunk 152: 128 words, 322 tokens (Valid: True)
# Chunk 153: 128 words, 320 tokens (Valid: True)
# Chunk 154: 128 words, 324 tokens (Valid: True)
# Chunk 155: 128 words, 335 tokens (Valid: True)
# Chunk 156: 128 words, 343 tokens (Valid: True)
# Chunk 157: 128 words, 321 tokens (Valid: True)
# Chunk 158: 128 words, 311 tokens (Valid: True)
# Chunk 159: 128 words, 317 tokens (Valid: True)
# Chunk 160: 128 words, 314 tokens (Valid: True)
# Chunk 161: 128 words, 304 tokens (Valid: True)
# Chunk 162: 128 words, 306 tokens (Valid: True)
# Chunk 163: 128 words, 287 tokens (Valid: True)
# Chunk 164: 128 words, 286 tokens (Valid: True)
# Chunk 165: 128 words, 285 tokens (Valid: True)
# Chunk 166: 128 words, 314 tokens (Valid: True)
# Chunk 167: 128 words, 313 tokens (Valid: True)
# Chunk 168: 128 words, 317 tokens (Valid: True)
# Chunk 169: 128 words, 316 tokens (Valid: True)
# Chunk 170: 128 words, 321 tokens (Valid: True)
# Chunk 171: 128 words, 312 tokens (Valid: True)
# Chunk 172: 128 words, 290 tokens (Valid: True)
# Chunk 173: 128 words, 305 tokens (Valid: True)
# Chunk 174: 128 words, 305 tokens (Valid: True)
# Chunk 175: 128 words, 326 tokens (Valid: True)
# Chunk 176: 128 words, 316 tokens (Valid: True)
# Chunk 177: 128 words, 316 tokens (Valid: True)
# Chunk 178: 128 words, 313 tokens (Valid: True)
# Chunk 179: 128 words, 321 tokens (Valid: True)
# Chunk 180: 128 words, 337 tokens (Valid: True)
# Chunk 181: 128 words, 324 tokens (Valid: True)
# Chunk 182: 128 words, 306 tokens (Valid: True)
# Chunk 183: 128 words, 325 tokens (Valid: True)
# Chunk 184: 128 words, 293 tokens (Valid: True)
# Chunk 185: 128 words, 297 tokens (Valid: True)
# Chunk 186: 128 words, 304 tokens (Valid: True)
# Chunk 187: 128 words, 330 tokens (Valid: True)
# Chunk 188: 128 words, 332 tokens (Valid: True)
# Chunk 189: 128 words, 333 tokens (Valid: True)
# Chunk 190: 128 words, 324 tokens (Valid: True)
# Chunk 191: 128 words, 328 tokens (Valid: True)
# Chunk 192: 128 words, 322 tokens (Valid: True)
# Chunk 193: 128 words, 326 tokens (Valid: True)
# Chunk 194: 128 words, 312 tokens (Valid: True)
# Chunk 195: 128 words, 312 tokens (Valid: True)
# Chunk 196: 128 words, 292 tokens (Valid: True)
# Chunk 197: 128 words, 310 tokens (Valid: True)
# Chunk 198: 128 words, 328 tokens (Valid: True)
# Chunk 199: 128 words, 312 tokens (Valid: True)
# Chunk 200: 128 words, 298 tokens (Valid: True)
# Chunk 201: 128 words, 325 tokens (Valid: True)
# Chunk 202: 128 words, 333 tokens (Valid: True)
# Chunk 203: 128 words, 312 tokens (Valid: True)
# Chunk 204: 128 words, 321 tokens (Valid: True)
# Chunk 205: 128 words, 328 tokens (Valid: True)
# Chunk 206: 128 words, 307 tokens (Valid: True)
# Chunk 207: 128 words, 294 tokens (Valid: True)
# Chunk 208: 128 words, 311 tokens (Valid: True)
# Chunk 209: 128 words, 299 tokens (Valid: True)
# Chunk 210: 128 words, 313 tokens (Valid: True)
# Chunk 211: 128 words, 316 tokens (Valid: True)
# Chunk 212: 128 words, 335 tokens (Valid: True)
# Chunk 213: 128 words, 369 tokens (Valid: True)
# Chunk 214: 128 words, 345 tokens (Valid: True)
# Chunk 215: 128 words, 358 tokens (Valid: True)
# Chunk 216: 128 words, 342 tokens (Valid: True)
# Chunk 217: 128 words, 325 tokens (Valid: True)
# Chunk 218: 128 words, 330 tokens (Valid: True)
# Chunk 219: 128 words, 339 tokens (Valid: True)
# Chunk 220: 128 words, 352 tokens (Valid: True)
# Chunk 221: 128 words, 356 tokens (Valid: True)
# Chunk 222: 128 words, 366 tokens (Valid: True)
# Chunk 223: 128 words, 351 tokens (Valid: True)
# Chunk 224: 128 words, 330 tokens (Valid: True)
# Chunk 225: 128 words, 348 tokens (Valid: True)
# Chunk 226: 128 words, 305 tokens (Valid: True)
# Chunk 227: 128 words, 287 tokens (Valid: True)
# Chunk 228: 128 words, 279 tokens (Valid: True)
# Chunk 229: 128 words, 313 tokens (Valid: True)
# Chunk 230: 128 words, 321 tokens (Valid: True)
# Chunk 231: 128 words, 311 tokens (Valid: True)
# Chunk 232: 128 words, 299 tokens (Valid: True)
# Chunk 233: 128 words, 324 tokens (Valid: True)
# Chunk 234: 128 words, 307 tokens (Valid: True)
# Chunk 235: 128 words, 324 tokens (Valid: True)
# Chunk 236: 128 words, 322 tokens (Valid: True)
# Chunk 237: 128 words, 325 tokens (Valid: True)
# Chunk 238: 128 words, 313 tokens (Valid: True)
# Chunk 239: 128 words, 327 tokens (Valid: True)
# Chunk 240: 128 words, 307 tokens (Valid: True)
# Chunk 241: 128 words, 319 tokens (Valid: True)
# Chunk 242: 128 words, 322 tokens (Valid: True)
# Chunk 243: 128 words, 330 tokens (Valid: True)
# Chunk 244: 128 words, 330 tokens (Valid: True)
# Chunk 245: 128 words, 326 tokens (Valid: True)
# Chunk 246: 128 words, 311 tokens (Valid: True)
# Chunk 247: 128 words, 322 tokens (Valid: True)
# Chunk 248: 128 words, 296 tokens (Valid: True)
# Chunk 249: 128 words, 286 tokens (Valid: True)
# Chunk 250: 128 words, 295 tokens (Valid: True)
# Chunk 251: 128 words, 288 tokens (Valid: True)
# Chunk 252: 128 words, 323 tokens (Valid: True)
# Chunk 253: 128 words, 338 tokens (Valid: True)
# Chunk 254: 128 words, 337 tokens (Valid: True)
# Chunk 255: 128 words, 327 tokens (Valid: True)
# Chunk 256: 128 words, 328 tokens (Valid: True)
# Chunk 257: 128 words, 327 tokens (Valid: True)
# Chunk 258: 128 words, 310 tokens (Valid: True)
# Chunk 259: 128 words, 343 tokens (Valid: True)
# Chunk 260: 128 words, 363 tokens (Valid: True)
# Chunk 261: 128 words, 369 tokens (Valid: True)
# Chunk 262: 128 words, 368 tokens (Valid: True)
# Chunk 263: 128 words, 331 tokens (Valid: True)
# Chunk 264: 128 words, 290 tokens (Valid: True)
# Chunk 265: 128 words, 284 tokens (Valid: True)
# Chunk 266: 128 words, 297 tokens (Valid: True)
# Chunk 267: 128 words, 322 tokens (Valid: True)
# Chunk 268: 128 words, 336 tokens (Valid: True)
# Chunk 269: 128 words, 336 tokens (Valid: True)
# Chunk 270: 128 words, 325 tokens (Valid: True)
# Chunk 271: 128 words, 344 tokens (Valid: True)
# Chunk 272: 128 words, 325 tokens (Valid: True)
# Chunk 273: 128 words, 320 tokens (Valid: True)
# Chunk 274: 128 words, 311 tokens (Valid: True)
# Chunk 275: 128 words, 308 tokens (Valid: True)
# Chunk 276: 128 words, 334 tokens (Valid: True)
# Chunk 277: 128 words, 313 tokens (Valid: True)
# Chunk 278: 128 words, 290 tokens (Valid: True)
# Chunk 279: 128 words, 285 tokens (Valid: True)
# Chunk 280: 128 words, 310 tokens (Valid: True)
# Chunk 281: 128 words, 326 tokens (Valid: True)
# Chunk 282: 128 words, 336 tokens (Valid: True)
# Chunk 283: 128 words, 376 tokens (Valid: True)
# Chunk 284: 128 words, 314 tokens (Valid: True)
# Chunk 285: 128 words, 329 tokens (Valid: True)
# Chunk 286: 128 words, 303 tokens (Valid: True)
# Chunk 287: 128 words, 313 tokens (Valid: True)
# Chunk 288: 128 words, 317 tokens (Valid: True)
# Chunk 289: 128 words, 346 tokens (Valid: True)
# Chunk 290: 128 words, 335 tokens (Valid: True)
# Chunk 291: 128 words, 309 tokens (Valid: True)
# Chunk 292: 128 words, 292 tokens (Valid: True)
# Chunk 293: 128 words, 295 tokens (Valid: True)
# Chunk 294: 128 words, 312 tokens (Valid: True)
# Chunk 295: 128 words, 321 tokens (Valid: True)
# Chunk 296: 128 words, 340 tokens (Valid: True)
# Chunk 297: 128 words, 331 tokens (Valid: True)
# Chunk 298: 128 words, 335 tokens (Valid: True)
# Chunk 299: 128 words, 343 tokens (Valid: True)
# Chunk 300: 128 words, 329 tokens (Valid: True)
# Chunk 301: 128 words, 323 tokens (Valid: True)
# Chunk 302: 128 words, 311 tokens (Valid: True)
# Chunk 303: 128 words, 313 tokens (Valid: True)
# Chunk 304: 128 words, 336 tokens (Valid: True)
# Chunk 305: 128 words, 321 tokens (Valid: True)
# Chunk 306: 128 words, 298 tokens (Valid: True)
# Chunk 307: 128 words, 290 tokens (Valid: True)
# Chunk 308: 128 words, 323 tokens (Valid: True)
# Chunk 309: 128 words, 319 tokens (Valid: True)
# Chunk 310: 128 words, 328 tokens (Valid: True)
# Chunk 311: 128 words, 355 tokens (Valid: True)
# Chunk 312: 128 words, 315 tokens (Valid: True)
# Chunk 313: 128 words, 326 tokens (Valid: True)
# Chunk 314: 128 words, 339 tokens (Valid: True)
# Chunk 315: 128 words, 332 tokens (Valid: True)
# Chunk 316: 128 words, 332 tokens (Valid: True)
# Chunk 317: 128 words, 339 tokens (Valid: True)
# Chunk 318: 128 words, 332 tokens (Valid: True)
# Chunk 319: 128 words, 323 tokens (Valid: True)
# Chunk 320: 128 words, 314 tokens (Valid: True)
# Chunk 321: 128 words, 315 tokens (Valid: True)
# Chunk 322: 128 words, 342 tokens (Valid: True)
# Chunk 323: 128 words, 348 tokens (Valid: True)
# Chunk 324: 128 words, 317 tokens (Valid: True)
# Chunk 325: 128 words, 323 tokens (Valid: True)
# Chunk 326: 128 words, 342 tokens (Valid: True)
# Chunk 327: 128 words, 346 tokens (Valid: True)
# Chunk 328: 128 words, 301 tokens (Valid: True)
# Chunk 329: 128 words, 324 tokens (Valid: True)
# Chunk 330: 128 words, 330 tokens (Valid: True)
# Chunk 331: 128 words, 314 tokens (Valid: True)
# Chunk 332: 128 words, 334 tokens (Valid: True)
# Chunk 333: 128 words, 303 tokens (Valid: True)
# Chunk 334: 128 words, 300 tokens (Valid: True)
# Chunk 335: 128 words, 309 tokens (Valid: True)
# Chunk 336: 128 words, 280 tokens (Valid: True)
# Chunk 337: 69 words, 159 tokens (Valid: True)

# %%
# Process the entire dataset
print("Processing entire dataset with tokenization and chunking...")
print("=" * 60)

chunked_data = []
original_row_ids = []
chunk_numbers = []

for idx, row in main_df.iterrows():
    text = row['text']
    labels = row['labels']
    
    # Check if chunking is needed
    token_count, is_valid = validate_chunk_tokens(text)
    
    if is_valid:
        # No chunking needed
        chunked_data.append({
            'text': text,
            'labels': labels,
            'original_row_id': idx,
            'chunk_number': 0,
            'total_chunks': 1,
            'token_count': token_count
        })
    else:
        # Chunking needed
        chunks = tokenize_and_chunk_text(text, labels, max_length=512, overlap=50)
        
        for chunk_idx, (chunk_text, chunk_labels) in enumerate(chunks):
            chunk_token_count, _ = validate_chunk_tokens(chunk_text)
            
            chunked_data.append({
                'text': chunk_text,
                'labels': chunk_labels,
                'original_row_id': idx,
                'chunk_number': chunk_idx,
                'total_chunks': len(chunks),
                'token_count': chunk_token_count
            })
    
    # Progress indicator
    if (idx + 1) % 50 == 0:
        print(f"Processed {idx + 1}/{len(main_df)} rows...")

# Create new DataFrame with chunked data
chunked_df = pd.DataFrame(chunked_data)

print(f"\nProcessing complete!")
print(f"Original dataset: {len(main_df)} rows")
print(f"Chunked dataset: {len(chunked_df)} rows")
print(f"Expansion factor: {len(chunked_df) / len(main_df):.2f}x")
# Out:
# Processing entire dataset with tokenization and chunking...
# ============================================================
# Processed 50/235 rows...
# Processed 100/235 rows...
# Processed 150/235 rows...
# Processed 200/235 rows...
#
# Processing complete!
# Original dataset: 235 rows
# Chunked dataset: 19387 rows
# Expansion factor: 82.50x

# %%
# Analyze the chunked dataset
print("Chunked Dataset Analysis:")
print("=" * 40)

# Basic statistics
print(f"Total rows: {len(chunked_df)}")
print(f"Rows that needed chunking: {len(chunked_df[chunked_df['total_chunks'] > 1])}")
print(f"Rows that didn't need chunking: {len(chunked_df[chunked_df['total_chunks'] == 1])}")

# Token count statistics
print(f"\nToken Count Statistics:")
print(f"Min tokens: {chunked_df['token_count'].min()}")
print(f"Max tokens: {chunked_df['token_count'].max()}")
print(f"Mean tokens: {chunked_df['token_count'].mean():.2f}")
print(f"Median tokens: {chunked_df['token_count'].median():.2f}")

# Check if all chunks are within token limit
valid_chunks = chunked_df['token_count'] <= 512
print(f"\nAll chunks within 512 token limit: {valid_chunks.all()}")
if not valid_chunks.all():
    invalid_chunks = chunked_df[~valid_chunks]
    print(f"Invalid chunks found: {len(invalid_chunks)}")
    print(invalid_chunks[['original_row_id', 'chunk_number', 'token_count']].head())

# Display sample of chunked data
print(f"\nSample of chunked dataset:")
print(chunked_df[['original_row_id', 'chunk_number', 'total_chunks', 'token_count']].head(10))

# Show distribution of chunk counts
chunk_distribution = chunked_df.groupby('original_row_id')['total_chunks'].first().value_counts().sort_index()
print(f"\nDistribution of chunks per original row:")
for chunks, count in chunk_distribution.items():
    print(f"  {chunks} chunk(s): {count} rows")
# Out:
# Chunked Dataset Analysis:
# ========================================
# Total rows: 19387
# Rows that needed chunking: 19387
# Rows that didn't need chunking: 0
#
# Token Count Statistics:
# Min tokens: 119
# Max tokens: 411
# Mean tokens: 320.56
# Median tokens: 321.00
#
# All chunks within 512 token limit: True
#
# Sample of chunked dataset:
#    original_row_id  chunk_number  total_chunks  token_count
# 0                0             0            88          342
# 1                0             1            88          342
# 2                0             2            88          326
# 3                0             3            88          367
# 4                0             4            88          315
# 5                0             5            88          352
# 6                0             6            88          337
# 7                0             7            88          306
# 8                0             8            88          279
# 9                0             9            88          310
#
# Distribution of chunks per original row:
#   30 chunk(s): 2 rows
#   32 chunk(s): 1 rows
#   38 chunk(s): 2 rows
#   39 chunk(s): 1 rows
#   40 chunk(s): 2 rows
#   41 chunk(s): 4 rows
#   42 chunk(s): 2 rows
#   43 chunk(s): 4 rows
#   45 chunk(s): 3 rows
#   46 chunk(s): 5 rows
#   47 chunk(s): 4 rows
#   48 chunk(s): 2 rows
#   49 chunk(s): 8 rows
#   50 chunk(s): 2 rows
#   51 chunk(s): 2 rows
#   52 chunk(s): 5 rows
#   53 chunk(s): 5 rows
#   54 chunk(s): 2 rows
#   55 chunk(s): 6 rows
#   56 chunk(s): 6 rows
#   57 chunk(s): 3 rows
#   58 chunk(s): 4 rows
#   59 chunk(s): 1 rows
#   60 chunk(s): 4 rows
#   61 chunk(s): 4 rows
#   62 chunk(s): 9 rows
#   63 chunk(s): 1 rows
#   64 chunk(s): 4 rows
#   65 chunk(s): 4 rows
#   66 chunk(s): 3 rows
#   67 chunk(s): 6 rows
#   68 chunk(s): 4 rows
#   69 chunk(s): 3 rows
#   70 chunk(s): 4 rows
#   71 chunk(s): 4 rows
#   73 chunk(s): 3 rows
#   74 chunk(s): 3 rows
#   75 chunk(s): 2 rows
#   76 chunk(s): 1 rows
#   77 chunk(s): 5 rows
#   78 chunk(s): 5 rows
#   79 chunk(s): 7 rows
#   80 chunk(s): 2 rows
#   81 chunk(s): 2 rows
#   82 chunk(s): 5 rows
#   83 chunk(s): 1 rows
#   84 chunk(s): 4 rows
#   85 chunk(s): 4 rows
#   87 chunk(s): 1 rows
#   88 chunk(s): 4 rows
#   89 chunk(s): 1 rows
#   90 chunk(s): 2 rows
#   92 chunk(s): 1 rows
#   93 chunk(s): 1 rows
#   95 chunk(s): 3 rows
#   96 chunk(s): 1 rows
#   97 chunk(s): 1 rows
#   98 chunk(s): 4 rows
#   99 chunk(s): 1 rows
#   101 chunk(s): 2 rows
#   103 chunk(s): 2 rows
#   104 chunk(s): 1 rows
#   105 chunk(s): 1 rows
#   106 chunk(s): 2 rows
#   107 chunk(s): 1 rows
#   109 chunk(s): 1 rows
#   112 chunk(s): 1 rows
#   114 chunk(s): 1 rows
#   115 chunk(s): 1 rows
#   116 chunk(s): 1 rows
#   120 chunk(s): 1 rows
#   121 chunk(s): 1 rows
#   127 chunk(s): 3 rows
#   129 chunk(s): 1 rows
#   130 chunk(s): 2 rows
#   132 chunk(s): 1 rows
#   141 chunk(s): 1 rows
#   142 chunk(s): 1 rows
#   143 chunk(s): 1 rows
#   145 chunk(s): 1 rows
#   147 chunk(s): 1 rows
#   150 chunk(s): 2 rows
#   157 chunk(s): 1 rows
#   171 chunk(s): 1 rows
#   180 chunk(s): 2 rows
#   185 chunk(s): 1 rows
#   203 chunk(s): 1 rows
#   210 chunk(s): 1 rows
#   219 chunk(s): 1 rows
#   221 chunk(s): 1 rows
#   224 chunk(s): 1 rows
#   265 chunk(s): 1 rows
#   274 chunk(s): 1 rows
#   282 chunk(s): 1 rows
#   293 chunk(s): 1 rows
#   337 chunk(s): 1 rows

# %%
chunked_df
# Out:
#                                                     text  \
# 0      PUTUSAN Nomor 192/Pid. B/2019/PN Bkl DEMI KEAD...
# 1      Dalam perkara ini, Terdakwa ditangkap oleh Pen...
# 2      Terdakwa serta memperhatikan Alat Bukti dan ba...
# 3      6 (enam) tahun dan 6 (enam) bulan dikurangi se...
# 4      rupiah); Setelah mendengar permohonan Terdakwa...
# ...                                                  ...
# 19382  -abu; yang telah dipergunakan untuk melakukan ...
# 19383  lain; Keadaan yang meringankan : - Tidak Ada ;...
# 19384  menyebabkan luka -luka berat ” sebagaimana dal...
# 19385  hitam liris -liris warna krem, biru ungu merah...
# 19386  Kn. , sebagai Hakim Ketua, Benny Haninta Surya...
#
#                                                   labels  original_row_id  \
# 0      O O B_VERN I_VERN I_VERN O O O O O O O O O O O...                0
# 1      O O O O O O O O O O O O O O O O O O O O O O O ...                0
# 2      O O O O O O O O O O O O O O O O O O O O O O O ...                0
# 3      B_PENA I_PENA I_PENA O O O O O O O O O O O O O...                0
# 4      O O O O O O O O O O O O O O O O O O O O O O O ...                0
# ...                                                  ...              ...
# 19382  O O O O O O O O O O O O O O O O O O O O O O O ...              234
# 19383  O O O O O O O O O O O O O O O O O O O O O O O ...              234
# 19384  O O O O O O O O O O O O O O O O O O O O O O B_...              234
# 19385  O O O O O O O O O O O O O O O O O O O O O O O ...              234
# 19386  I_JUDP I_JUDP O O O B_JUDG I_JUDG I_JUDG I_JUD...              234
#
#        chunk_number  total_chunks  token_count
# 0                 0            88          342
# 1                 1            88          342
# 2                 2            88          326
# 3                 3            88          367
# 4                 4            88          315
# ...             ...           ...          ...
# 19382            84            89          313
# 19383            85            89          329
# 19384            86            89          322
# 19385            87            89          286
# 19386            88            89          237
#
# [19387 rows x 6 columns]

# %%
# Save the chunked dataset
output_path = '../../Datasets/FINAL/DATASET_BERT_CHUNKED.csv'

# Drop all rows that contain only 'O' annotation in the labels
chunked_df = chunked_df[~chunked_df['labels'].apply(lambda x: all(label == 'O' for label in x.split()))].reset_index(drop=True)


chunked_df.to_csv(output_path, index=False)



print(f"Chunked dataset saved to: {output_path}")

# Display final dataset structure
print(f"\nFinal chunked dataset:")
print(chunked_df.head())

# Show some examples of chunked vs original data
print(f"\nExample of chunking (first row that was split):")
multi_chunk_rows = chunked_df[chunked_df['total_chunks'] > 1]['original_row_id'].unique()
if len(multi_chunk_rows) > 0:
    example_row_id = multi_chunk_rows[0]
    original_example = main_df.iloc[example_row_id]
    chunked_examples = chunked_df[chunked_df['original_row_id'] == example_row_id]
    
    print(f"\nOriginal row {example_row_id}:")
    print(f"  Length: {len(original_example['text'])} chars, {len(original_example['text'].split())} words")
    print(f"  Preview: {original_example['text'][:200]}...")
    
    print(f"\nSplit into {len(chunked_examples)} chunks:")
    for _, chunk in chunked_examples.iterrows():
        print(f"  Chunk {chunk['chunk_number']}: {len(chunk['text'].split())} words, {chunk['token_count']} tokens")
        print(f"    Preview: {chunk['text'][:150]}...")
        print()
# Out:
# Chunked dataset saved to: ../../Datasets/FINAL/DATASET_BERT_CHUNKED.csv
#
# Final chunked dataset:
#                                                 text  \
# 0  PUTUSAN Nomor 192/Pid. B/2019/PN Bkl DEMI KEAD...
# 1  Dalam perkara ini, Terdakwa ditangkap oleh Pen...
# 2  Terdakwa serta memperhatikan Alat Bukti dan ba...
# 3  6 (enam) tahun dan 6 (enam) bulan dikurangi se...
# 4  rupiah); Setelah mendengar permohonan Terdakwa...
#
#                                               labels  original_row_id  \
# 0  O O B_VERN I_VERN I_VERN O O O O O O O O O O O...                0
# 1  O O O O O O O O O O O O O O O O O O O O O O O ...                0
# 2  O O O O O O O O O O O O O O O O O O O O O O O ...                0
# 3  B_PENA I_PENA I_PENA O O O O O O O O O O O O O...                0
# 4  O O O O O O O O O O O O O O O O O O O O O O O ...                0
#
#    chunk_number  total_chunks  token_count
# 0             0            88          342
# 1             1            88          342
# 2             2            88          326
# 3             3            88          367
# 4             4            88          315
#
# Example of chunking (first row that was split):
#
# Original row 0:
#   Length: 49200 chars, 6880 words
#   Preview: PUTUSAN Nomor 192/Pid. B/2019/PN Bkl DEMI KEADILAN BERDASARKAN KETUHANAN YANG MAHA ESA Pengadilan Negeri Bangkalan yang mengadili perkara pidana dengan acara pemeriksaan biasa dalam tingkat pertama me...
#
# Split into 27 chunks:
#   Chunk 0: 128 words, 342 tokens
#     Preview: PUTUSAN Nomor 192/Pid. B/2019/PN Bkl DEMI KEADILAN BERDASARKAN KETUHANAN YANG MAHA ESA Pengadilan Negeri Bangkalan yang mengadili perkara pidana denga...
#
#   Chunk 1: 128 words, 342 tokens
#     Preview: Dalam perkara ini, Terdakwa ditangkap oleh Penyidik dalam perkara lain; Terdakwa ditahan dalam perkara lain; Terdakwa menghadap sendiri dan tidak dida...
#
#   Chunk 2: 128 words, 326 tokens
#     Preview: Terdakwa serta memperhatikan Alat Bukti dan barang bukti yang diajukan di persidangan; Setelah mendengar pembacaan tuntutan pidana yang diajukan oleh ...
#
#   Chunk 3: 128 words, 367 tokens
#     Preview: 6 (enam) tahun dan 6 (enam) bulan dikurangi selama Terdakwa berada dalam tahanan dan dengan perintah tetap ditahan; 3. Menyatakan Barang bukti berupa:...
#
#   Chunk 4: 128 words, 315 tokens
#     Preview: rupiah); Setelah mendengar permohonan Terdakwa yang pada pokoknya menyatakan meminta keringanan atas tuntutan yang diajukan oleh Penuntut Umum; Menimb...
#
#   Chunk 6: 128 words, 337 tokens
#     Preview: memungkinkan bagi dirinya atau lain-lain peserta di dalam kejahatan melar ikan diri ataupun untuk menamin pemilikannya atau tersebut dilakukan terhada...
#
#   Chunk 7: 128 words, 306 tokens
#     Preview: Suzuki Satria warna hitam Nopol . M 6452 HM yang dipinjam dari Saksi Samsul Arifin. Untuk mempermudah Terdakwa melakukan aksinya menggunakan masker wa...
#
#   Chunk 8: 128 words, 279 tokens
#     Preview: hendak naik namun tida k jadi dan Saksi Leni Marethasari turun dari bus dan berdiri di pintu keluar SPBU. Terdakwa H. Abd Aziz Al. H. Aziz kemudian me...
#
#   Chunk 13: 128 words, 321 tokens
#     Preview: Puluh Ribu) Terdakwa gunakan untuk membeli Narkotika jenis Sabu. Sedangkan sisanya sejumlah Rp720. 000 ,00 (Tujuh Ratus Dua Puluh Ribu Rupiah) Terdakw...
#
#   Chunk 14: 128 words, 319 tokens
#     Preview: sebagaimana diatur dan diancam tindak Pidana dalam Pasal 365 Ayat (2) ke-1 K itab Undang-Undang Hukum Pidana ; Bahwa ia Terdakwa H. Abd Aziz Al. H. Az...
#
#   Chunk 16: 128 words, 327 tokens
#     Preview: Marethasari. Perbuatan mana dilakukan Terdakwa dengan cara antara lain sebagai berikut : -Pada waktu dan tempat sebagaimana telah disebutkan diatas be...
#
#   Chunk 17: 128 words, 302 tokens
#     Preview: dan menanyakan kepada Saksi Leni Marethasari dengan mengatakan “Mbak disini SPBU cuma disini saja?”, Saksi Leni Marethasari menjawab “Iya” kemudian Te...
#
#   Chunk 18: 128 words, 300 tokens
#     Preview: H. Aziz kemudian mengatakan kepada Saksi Leni Marethasari “Sudah tunggu saja mbak nanti akan banyak Bus lewat Saksi juga masih menunggu orang”, sekita...
#
#   Chunk 22: 128 words, 332 tokens
#     Preview: sebanyak Rp280. 000,00 (Dua Ratus Delapan Puluh Ribu) Terdakwa gunakan untuk membeli Narkotika jenis Sabu. Sedangkan sisanya sejumlah Rp720. 000,00 (T...
#
#   Chunk 23: 128 words, 300 tokens
#     Preview: tindak Pidana dalam Pasal 365 Ayat ( 1) Kitab Undang-Undang Hukum Pidana; LEBIH SUBSIDAIR; Bahwa ia Terdakwa H. Abd Aziz Al. H. Aziz , pada hari Sabtu...
#
#   Chunk 27: 128 words, 298 tokens
#     Preview: warna hitam dengan Nopol M 6452 HM yang Terdakwa pinjam dari Saksi Samsul Arifin dan dengan maksud memiliki barang secara melawan hukum dengan mengamb...
#
#   Chunk 28: 128 words, 318 tokens
#     Preview: Handphone milik Saksi Leni Marethasari selanjutnya Terdakwa menukar tambahkan Handphone tersebut kepada Saksi Heji di warungnya di Jalan Raya Tangkel ...
#
#   Chunk 56: 128 words, 374 tokens
#     Preview: sejumlah Rp2. 650. 000,00 (dua juta enam ratus lima puluh ribu rupiah); Menimbang, bahwa selanjutnya Majelis Hakim akan mempertimbangkan apakah berdas...
#
#   Chunk 62: 128 words, 352 tokens
#     Preview: yang berjudul Leerboek I yaitu menyangkut masalah pertumbuhan akal sehat yang tidak sempurna atau karena gangguan penyakit pada kemampuan akal sehat h...
#
#   Chunk 63: 128 words, 360 tokens
#     Preview: dalam persidangan mampu menjawab dengan baik menyangkut segala pertanyaan maupun tanggapan yang diajukan; Menimbang, bahwa selama berjalannya proses p...
#
#   Chunk 64: 128 words, 341 tokens
#     Preview: dan Tuntutan Pidana Penuntut Umum, serta clemensie dari Terdakwa sendiri di depan persidangan dan pembenaran Terdakwa terhadap pemeriksaan identitasny...
#
#   Chunk 79: 128 words, 334 tokens
#     Preview: Terdakwa dengan mengambil barang orang lain dalam hal ini berupa 1 (satu) unit Handphone merek Samsung Galaxy A6 warna hitam milik Saksi Leny Marethas...
#
#   Chunk 80: 128 words, 358 tokens
#     Preview: primair Penuntut Umum ; Menimbang bahwa dakwaan Penuntut Umum berbentuk subsidairitas, oleh karena dakwaan primair telah terbukti maka dakwaan subsida...
#
#   Chunk 84: 128 words, 373 tokens
#     Preview: meringankan Terdakwa; Keadaan yang memberatkan : -Perbuatan Terdakwa meresahkan masyarakat; -Terdakwa telah menikmati hasil kejahatannya; Keadaan yang...
#
#   Chunk 85: 128 words, 364 tokens
#     Preview: dan memperhatikan, Pasal 365 ayat (2) ke-1 Kitab Undang- Undang Hukum Pidana dan Undang-undang Nomor 8 Tahun 1981 tentang Hukum Acara Pidana serta per...
#
#   Chunk 86: 128 words, 343 tokens
#     Preview: Samsung Galaxi A6 warna hitam dengan No. IMEI 357931/09/412666/6, IMEI 357932/09 /412666/4; -1 (satu) buah Handphone Samsung Galaxi A6 warna hitam den...
#
#   Chunk 87: 94 words, 221 tokens
#     Preview: dan ANASTASIA IRENE, S. H. ,M. H , masing-masing sebagai Hakim Anggota, yang diucapkan dalam sidang terbuka untuk umum pada hari Rabu tanggal 7 Agustu...

# %%
# Helper functions for working with chunked data during training

def prepare_bert_input(chunked_df, tokenizer, max_length=512):
    """
    Prepare tokenized inputs for BERT training from chunked dataset.
    
    Args:
        chunked_df: DataFrame with chunked text and labels
        tokenizer: BERT tokenizer
        max_length: Maximum sequence length
    
    Returns:
        Dictionary with input_ids, attention_mask, and labels
    """
    texts = chunked_df['text'].tolist()
    labels = chunked_df['labels'].tolist()
    
    # Tokenize texts
    encodings = tokenizer(texts, 
                            truncation=True, 
                            padding=True, 
                            max_length=max_length, 
                            return_tensors='pt')
    
    # Process labels (convert to label IDs if needed)
    processed_labels = []
    for label_str in labels:
        label_tokens = label_str.split()
        processed_labels.append(label_tokens)
    
    return {
        'input_ids': encodings['input_ids'],
        'attention_mask': encodings['attention_mask'],
        'labels': processed_labels,
        'original_row_ids': chunked_df['original_row_id'].tolist(),
        'chunk_numbers': chunked_df['chunk_number'].tolist()
    }

def reconstruct_predictions(predictions, chunked_df, overlap=50):
    """
    Reconstruct full document predictions from chunked predictions.
    
    Args:
        predictions: List of predictions for each chunk
        chunked_df: DataFrame with chunked data
        overlap: Number of overlapping tokens between chunks
    
    Returns:
        Dictionary mapping original_row_id to reconstructed predictions
    """
    reconstructed = {}
    
    for original_row_id in chunked_df['original_row_id'].unique():
        chunk_data = chunked_df[chunked_df['original_row_id'] == original_row_id].sort_values('chunk_number')
        
        if len(chunk_data) == 1:
            # Single chunk, no reconstruction needed
            chunk_idx = chunk_data.index[0]
            reconstructed[original_row_id] = predictions[chunk_idx]
        else:
            # Multiple chunks, need to reconstruct
            reconstructed_pred = []
            
            for i, (_, chunk_row) in enumerate(chunk_data.iterrows()):
                chunk_idx = chunk_row.name
                chunk_pred = predictions[chunk_idx]
                
                if i == 0:
                    # First chunk: take all predictions
                    reconstructed_pred.extend(chunk_pred)
                else:
                    # Subsequent chunks: skip overlap tokens
                    reconstructed_pred.extend(chunk_pred[overlap:])
            
            reconstructed[original_row_id] = reconstructed_pred
    
    return reconstructed

print("Helper functions for BERT training with chunked data created!")
print("\nYou can now use the chunked dataset for training without token overflow issues.")
print("Key functions available:")
print("- prepare_bert_input(): Prepare data for BERT training")
print("- reconstruct_predictions(): Reconstruct full predictions from chunks")
# Out:
# Helper functions for BERT training with chunked data created!
#
# You can now use the chunked dataset for training without token overflow issues.
# Key functions available:
# - prepare_bert_input(): Prepare data for BERT training
# - reconstruct_predictions(): Reconstruct full predictions from chunks

# %%
# Final analysis of chunked dataset
print("Final Chunked Dataset Analysis:")
print("=" * 50)

# Basic statistics
print(f"Total rows: {len(chunked_df)}")
print(f"Rows that needed chunking: {len(chunked_df[chunked_df['total_chunks'] > 1])}")
print(f"Rows that didn't need chunking: {len(chunked_df[chunked_df['total_chunks'] == 1])}")

# Token count statistics
print(f"\nToken Count Statistics:")
print(f"Min tokens: {chunked_df['token_count'].min()}")
print(f"Max tokens: {chunked_df['token_count'].max()}")
print(f"Mean tokens: {chunked_df['token_count'].mean():.2f}")
print(f"Median tokens: {chunked_df['token_count'].median():.2f}")

# Check if all chunks are within token limit
valid_chunks = chunked_df['token_count'] <= 512
print(f"\nAll chunks within 512 token limit: {valid_chunks.all()}")
if not valid_chunks.all():
    invalid_chunks = chunked_df[~valid_chunks]
    print(f"Invalid chunks found: {len(invalid_chunks)}")
    print(invalid_chunks[['original_row_id', 'chunk_number', 'token_count']].head())
else:
    print("✅ All chunks are valid!")

# Save the chunked dataset
output_path = '../../Datasets/FINAL/DATASET_BERT_CHUNKED.csv'
chunked_df.to_csv(output_path, index=False)
print(f"\n💾 Chunked dataset saved to: {output_path}")

# Show final statistics
print(f"\n📊 Final Statistics:")
print(f"   Original rows: 235")
print(f"   Chunked rows: {len(chunked_df):,}")
print(f"   Expansion factor: {len(chunked_df) / 235:.1f}x")
print(f"   Average tokens per chunk: {chunked_df['token_count'].mean():.0f}")
print(f"   Token efficiency: {chunked_df['token_count'].mean() / 512 * 100:.1f}%")

print("\n🎉 Tokenization and chunking process completed successfully!")
print("The dataset is now ready for BERT training without token overflow issues.")
# Out:
# Final Chunked Dataset Analysis:
# ==================================================
# Total rows: 4930
# Rows that needed chunking: 4930
# Rows that didn't need chunking: 0
#
# Token Count Statistics:
# Min tokens: 119
# Max tokens: 405
# Mean tokens: 318.11
# Median tokens: 323.00
#
# All chunks within 512 token limit: True
# ✅ All chunks are valid!
#
# 💾 Chunked dataset saved to: ../../Datasets/FINAL/DATASET_BERT_CHUNKED.csv
#
# 📊 Final Statistics:
#    Original rows: 235
#    Chunked rows: 4,930
#    Expansion factor: 21.0x
#    Average tokens per chunk: 318
#    Token efficiency: 62.1%
#
# 🎉 Tokenization and chunking process completed successfully!
# The dataset is now ready for BERT training without token overflow issues.

# %% [markdown]
# ----

# %%
temp = pd.read_csv('../../Datasets/FINAL/DATASET_BERT_CHUNKED.csv')

# %%
temp
# Out:
#                                                    text  \
# 0     PUTUSAN Nomor 192/Pid. B/2019/PN Bkl DEMI KEAD...
# 1     Dalam perkara ini, Terdakwa ditangkap oleh Pen...
# 2     Terdakwa serta memperhatikan Alat Bukti dan ba...
# 3     6 (enam) tahun dan 6 (enam) bulan dikurangi se...
# 4     rupiah); Setelah mendengar permohonan Terdakwa...
# ...                                                 ...
# 4925  -abu; yang telah dipergunakan untuk melakukan ...
# 4926  lain; Keadaan yang meringankan : - Tidak Ada ;...
# 4927  menyebabkan luka -luka berat ” sebagaimana dal...
# 4928  hitam liris -liris warna krem, biru ungu merah...
# 4929  Kn. , sebagai Hakim Ketua, Benny Haninta Surya...
#
#                                                  labels  original_row_id  \
# 0     O O B_VERN I_VERN I_VERN O O O O O O O O O O O...                0
# 1     O O O O O O O O O O O O O O O O O O O O O O O ...                0
# 2     O O O O O O O O O O O O O O O O O O O O O O O ...                0
# 3     B_PENA I_PENA I_PENA O O O O O O O O O O O O O...                0
# 4     O O O O O O O O O O O O O O O O O O O O O O O ...                0
# ...                                                 ...              ...
# 4925  O O O O O O O O O O O O O O O O O O O O O O O ...              234
# 4926  O O O O O O O O O O O O O O O O O O O O O O O ...              234
# 4927  O O O O O O O O O O O O O O O O O O O O O O B_...              234
# 4928  O O O O O O O O O O O O O O O O O O O O O O O ...              234
# 4929  I_JUDP I_JUDP O O O B_JUDG I_JUDG I_JUDG I_JUD...              234
#
#       chunk_number  total_chunks  token_count
# 0                0            88          342
# 1                1            88          342
# 2                2            88          326
# 3                3            88          367
# 4                4            88          315
# ...            ...           ...          ...
# 4925            84            89          313
# 4926            85            89          329
# 4927            86            89          322
# 4928            87            89          286
# 4929            88            89          237
#
# [4930 rows x 6 columns]
